# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment
import ast
import re
import unicodedata

# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment
import ast, re

# Input file
input_file = "websites_schools_results.xlsx"
output_file = "sample.xlsx"

# Load data
df = pd.read_excel(input_file)

df["domain"] = df["domain"].fillna("")

# Create workbook
wb = Workbook()
ws = wb.active

row_cursor = 1  # keep track of where we are in the new sheet

# Définir des styles
title_fill = PatternFill(start_color="4F81BD", end_color="4F81BD", fill_type="solid")  # bleu
header_fill = PatternFill(start_color="BDD7EE", end_color="BDD7EE", fill_type="solid")  # bleu clair
label_fill = PatternFill(start_color="F2F2F2", end_color="F2F2F2", fill_type="solid")  # gris clair

title_font = Font(color="FFFFFF", bold=True, size=14)
header_font = Font(color="000000", bold=True)
label_font = Font(color="000000", bold=True)

def normalize_text(text):
    """Supprime les accents et caractères spéciaux d'une chaîne"""
    if not isinstance(text, str):
        return ""
    # Transformer en forme décomposée puis supprimer les diacritiques
    text = unicodedata.normalize("NFD", text)
    text = "".join(c for c in text if unicodedata.category(c) != "Mn")
    # Remplacer espaces/tirets par un seul séparateur
    text = text.replace(" ", "").replace("-", "")
    return text.lower()

def detect_email_pattern(emails_list):
    """Détecte le pattern dominant avec priorité stricte"""
    if not emails_list:
        return ""

    samples = [e.split("@")[0] for e in emails_list if "@" in e]

    # priorité : prenom.nom > p.nom > premiere_lettre_prenomNom
    if any(re.match(r"^[a-z]+\.[a-z]+$", s) for s in samples):
        return "prenom.nom"
    if any(re.match(r"^[a-z]\.[a-z]+$", s) for s in samples):
        return "premiere_lettre_prenom.nom"
    if any(re.match(r"^[a-z]+$", s) for s in samples):
        return "premiere_lettre_prenomNom"

    return ""


def generate_email(name, domain, pattern):
    """Construit un email à partir d'un nom complet, d'un domaine et d'un pattern"""
    if not isinstance(name, str) or not name.strip():
        return None
    
    parts = name.strip().split()
    if len(parts) < 2:
        return None
    
    prenom = normalize_text(parts[0])
    nom = normalize_text(parts[-1])

    if pattern == "prenom.nom":
        local = f"{prenom}.{nom}"
    elif pattern == "premiere_lettre_prenom.nom":
        local = f"{prenom[0]}.{nom}"
    elif pattern == "premiere_lettre_prenomNom":
        local = f"{prenom[0]}{nom}"
    else:
        local = f"{prenom}.{nom}"  # fallback

    return f"{local}@{domain}"


for _, row in df.iterrows():
    name = row["name"]
    website = row["website"]
    domain = row["domain"]
    emails = row["emails"]
    staff_list = row["staff"]
    
    email_list = []

    if isinstance(emails, str):
        emails = emails.strip()
        if emails.lower() not in ("", "set()"):
            try:
                parsed = ast.literal_eval(emails)  # parse string into Python object
                if isinstance(parsed, list):
                    for item in parsed:
                        if isinstance(item, set):
                            for val in item:
                                email_list.append(val.strip("'").strip())
                        elif isinstance(item, str):
                            email_list.append(item.strip("'").strip())
                elif isinstance(parsed, set):
                    for val in parsed:
                        email_list.append(val.strip("'").strip())
            except Exception as e:
                print("Parsing error:", e)
                email_list = []

    # --- Garder uniquement les emails du domaine ---
    if isinstance(domain, str) and domain:
        email_list = [e for e in email_list if e.endswith("@" + domain)]
        
    # --- Collect staff emails ---
    staff_emails = []
    if isinstance(staff_list, str):
        try:
            staff_list = ast.literal_eval(staff_list)
        except:
            staff_list = []

    if isinstance(staff_list, list):
        for staff in staff_list:
            if staff.get("email"):
                staff_emails.append(staff["email"])

    # --- Priorité : utiliser staff_emails si dispo, sinon email_list ---
    emails_for_pattern = staff_emails if staff_emails else email_list
    pattern = detect_email_pattern(emails_for_pattern)
    
    # --- First row: Name spanning 4 columns ---
    ws.merge_cells(start_row=row_cursor, start_column=1, end_row=row_cursor, end_column=4)
    cell = ws.cell(row=row_cursor, column=1, value=name)
    cell.fill = title_fill
    cell.font = title_font
    cell.alignment = Alignment(horizontal="center")
    row_cursor += 1

    # --- Website row ---
    ws.cell(row=row_cursor, column=1, value="Site web").fill = label_fill
    ws.cell(row=row_cursor, column=1).font = label_font
    ws.cell(row=row_cursor, column=2, value=website)
    row_cursor += 1

    # --- Domain row ---
    ws.cell(row=row_cursor, column=1, value="Email domaine").fill = label_fill
    ws.cell(row=row_cursor, column=1).font = label_font
    ws.cell(row=row_cursor, column=2, value=domain)
    row_cursor += 1
    
    print(domain, name)


    # --- Emails row ---
    ws.cell(row=row_cursor, column=1, value="Emails scrapés").fill = label_fill
    ws.cell(row=row_cursor, column=1).font = label_font
    if isinstance(emails, str) and emails.strip().lower() not in ("set()", ""):
        ws.cell(row=row_cursor, column=2, value=emails)
    else:
        ws.cell(row=row_cursor, column=2, value="")
    row_cursor += 1

    # --- Email shape suggested row ---
    ws.cell(row=row_cursor, column=1, value="Forme de l'email suggéré").fill = label_fill
    ws.cell(row=row_cursor, column=1).font = label_font
    ws.cell(row=row_cursor, column=2, value=pattern)
    row_cursor += 1

    # --- Staff table header ---
    headers = ["Nom complet", "Rôle", "Email trouvé", "Email suggéré"]
    for col, h in enumerate(headers, start=1):
        c = ws.cell(row=row_cursor, column=col, value=h)
        c.fill = header_fill
        c.font = header_font
        c.alignment = Alignment(horizontal="center")
    row_cursor += 1

    # --- Staff rows ---
    if isinstance(staff_list, str):
        try:
            staff_list = ast.literal_eval(staff_list)
        except:
            staff_list = []
    
    if isinstance(staff_list, list):
        for staff in staff_list:
            ws.cell(row=row_cursor, column=1, value=staff.get("name"))
            ws.cell(row=row_cursor, column=2, value=staff.get("function"))
            ws.cell(row=row_cursor, column=3, value=staff.get("email"))

            suggested = None
            if not staff.get("email") and domain:  # only if email is missing/None/empty
                suggested = generate_email(staff.get("name", ""), domain, pattern)

            ws.cell(row=row_cursor, column=4, value=suggested if suggested else "")
            row_cursor += 1

    # --- Leave two empty rows between blocks ---
    row_cursor += 2

# Ajuster largeur colonnes
for col in range(1, 5):
    ws.column_dimensions[chr(64 + col)].width = 30

# Save
wb.save(output_file)
print(f"✅ File created with email patterns: {output_file}")
# Out:
# purpan.fr École d’Ingénieurs de PURPAN
# esc-cybersecurity.com European School of Cybersecurity
# dsti.institute DSTI School of Engineering - French Riviera
# dsti.institute DSTI School of Engineering - Paris
# difcam.com CFA DIFCAM Ile-de-France
# purple-campus.com Purple Campus - Alès
# iffp.pro IFFP - Institut Français de Formation Professionnelle
# purple-campus.com Purple Campus - Nîmes
# carcassonne-agglo.fr Purple Campus - Carcassonne
# purple-campus.com Purple Campus - Narbonne
# isal-paris.fr ISAL PARIS
# ief2i.fr Digital School of Paris
# fms-school.com SMBS - L'école de commerce de la santé - Paris
#  emlyon business school - Campus de Lyon
# digital-college.fr Digital College - Lyon
# digital-college.fr Digital College - Paris La Défense
#  301
# efrei.fr Efrei - Ecole d'ingénieur - Informatique et technologies du numérique - Paris
# clermont-sb.fr Clermont School of Business
# afip-formations.com AFIP Formations
# supexpertise.fr Sup'Expertise
# fms-school.com FMS - L’école de commerce du Food Business - Paris
# mbseducation.fr MBS EDUCATION
# aurlom.com Aurlom BTS +
# h3campus.fr H3 Campus Paris
# antemed-epsilon.fr Antemed Epsilon
# mbway.com MBway - Lyon
# ecolegarti.com GARTI - École Supérieure de Graphisme
# financia-bs.com Financia Business School - Paris
# mydigitalschool.com MyDigitalSchool - Lyon
# euridis.net Euridis Business School - Campus de Nantes
# euridis.net Euridis Business School - Campus d'Aix-en-Provence
# em-normandie.fr Ecole de Management de Normandie - Caen
# exchange-college.com EXCHANGE COLLEGE- Paris
# mydigitalschool.com MyDigitalSchool - Lille
# mydigitalschool.com MyDigitalSchool - Nice
# gmail.com Elégance Académies
# digital-campus.fr Digital Campus - Paris
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - REIMS
# ppa.fr PPA BUSINESS SCHOOL - LILLE
# ppa.fr PPA BUSINESS SCHOOL - GRENOBLE
# edcparis.edu EDC Paris Business School
# eductive.fr EFET CREA - AIX-EN-PROVENCE
# eductive.fr EFET CRÉA - LILLE
# reseau-ges.fr EFFICOM DESIGN SCHOOL - LILLE
# reseau-ges.fr EFFICOM BUSINESS SCHOOL - PARIS
# efab.fr EFAB - GRENOBLE
# efab.fr EFAB IMMOBILIER - LYON
# efab.fr EFAB IMMOBILIER - LILLE
# eductive.fr EDBS - LILLE
# talisformation.com TALIS Paris
# lh.school Luxury Hotelschool Paris
# esupcom.com ESUPCOM - ECOLE SUPERIEURE DE COMMUNICATION - AIX-EN-PROVENCE
# esarc-evolution.fr ESARC Toulouse
# studio-m.fr STUDIO M - Montpellier
# ecoris.com ECORIS - Chambéry
# emc.fr Ecole supérieure des métiers de l’image, du son et de la création 2D-3D
# gmail.com ECORIS - Annecy
# aforem.fr AFOREM Rennes
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Rennes
# builders-ingenieurs.fr BUILDERS École d’ingénieurs
# ecema.fr Ecole supérieure européenne de management en alternance - Lyon
# esitc-paris.fr ESITC - Ecole supérieure d'Ingénieurs des Travaux de la Construction de Paris
# gip-cei.com Ecole Supérieure de Logistique Industrielle Redon
# esic.fr ESIC - Ecole Supérieure Informatique et de Commerce - Paris
#  ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - PARIS
# esgci.com ESGCI
# esgf.com ESG - Ecole Supérieure de Gestion et Finance Paris
# efab.fr EFAB IMMOBILIER - TOULON
# reseau-ges.fr ENGDE - ECOLE SUPERIEURE DE GESTION & D'EXPERTISE COMPTABLE - PARIS
# escaet.fr Ecole supérieure de commerce et de management spécialisée Tourisme
# sciences-u.fr EFET CREA - LYON
#  Suptertiaire - Campus de Paris
# esdm-formation.fr ESDM - École Nantaise du Développement Durable & de Management
# eductive.fr EFET CREA - NANTES
# ppa.fr PPA BUSINESS SCHOOL - NANTES
# eductive.fr PPA SPORT - REIMS
# eductive.fr PPA SPORT - LILLE
# grenoble-em.com GEM - Grenoble Ecole de Management - Campus de Grenoble
# letudiant.fr ECITV - Ecole du Web, du Digital et de l’Audiovisuel en alternance
# letudiant.fr ECITV - La Grande École du Digital, du Web et de l’Audiovisuel en alternance - Lille
#  EIML - ECOLE INTERNATIONALE DE MARKETING DU LUXE - LILLE
# reseau-ges.fr EIML - ECOLE INTERNATIONALE DE MARKETING DU LUXE - AIX
# competences-developpement.fr WIS Rennes
# alterneoecole.fr Alterneo - Paris
# mbway.com MBway - Paris Sud
# figs-education.com IET - L’Institut des métiers de l’Environnement et de la Transition écologique - Lyon
# figs-education.com IET - L’Institut des métiers de l’Environnement et de la Transition écologique - Nantes
#  Ecole IT - Campus d'Orléans
# ecole-it.com Ecole IT - Campus de Valenciennes
#  ICAN - Institut de création et d'animation numériques - LYON
# brest-opencampus.com HTBS - Brest
# aforem.fr AFOREM Le Mans
# competences-developpement.fr EPSI Auxerre
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Montpellier
# competences-developpement.fr IEFT - Institut européen de formation au tourisme - Bordeaux
# figs-education.com IGEFI - Paris
# figs-education.com IGEFI - Lyon
# ecema.fr Ecole supérieure européenne de management en alternance - Bourges
# ikigai-education.com Studency
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - Toulouse
# iscparis.com ISC - Institut Supérieur du Commerce - Campus de Paris
# digital-college.fr Digital College - Lille
# aivancity.ai Aivancity - La Grande École de l'Intelligence Artificielle et de la Data
# digital-college.fr Digital College - Marseille
# holbertonschool.com Holberton Paris
# eductive.fr ISA - l’institut supérieur d’audiovisuel - Paris
# ppa.fr PPA BUSINESS SCHOOL - Toulon
# maestris.com MAESTRIS BTS - NANTES
# supdevinci.fr SUP DE VINCI - Bordeaux
# iso.fr ISO - Institut Supérieur d'Optique Lyon
# iso.fr ISO - Institut Supérieur d'Optique Paris
# emineo-education.fr ISVM - Institut de Santé du Vivant et du Médico-social - Bordeaux
# groupe-ipf.com IRIS - Ecole Supérieur d'informatique et de Numérique - Paris
# isffel.fr ISFFEL - Saint Pol-de-Léon
# iscom.fr ISCOM - Institut supérieur de communication et de publicité - Lyon
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - PARIS
# iscom.fr ISCOM - Institut supérieur de communication et de publicité - Lille
# ecole-energietech.fr L'Ecole Energie Tech
# competences-developpement.fr SUP'DE COM - Lyon
# institutlyfe.com Institut Lyfe, Management en Arts Culinaires & Hôtellerie
# institut-g4.fr Institut G4 - Marseille
# audencia.com Audencia SciencesCom - MediaCampus
# ppa.fr PPA BUSINESS SCHOOL - PARIS
# pigier.com Ecole Pigier - Nantes
# eslsca.fr ESLSCA Business School
# pigier.com Ecole Pigier - Nice
# pigier.com Ecole Pigier - Nîmes
# pigier.com Ecole Pigier - Montpellier
# esicad.com ESICAD - Ecole supérieure privée de commerce et gestion - Toulouse
# omneseducation.com Sup Career Paris - Omnes Education
# talis-bs.com Talis Bordeaux
# bellecour.fr Bellecour École, école de design, d’animation et de jeu vidéo à Lyon
# ispn.fr ISPN - Institut Supérieur Professionnel de Caen
# sportsmanagementschool.fr Sports Management School
# eemi.com EEMI - Ecole Européenne des Metiers de l'Internet - Paris
# letudiant.fr L’ECITV, La Grande École du Digital, du Web et de l’Audiovisuel en alternance - Paris
# reseau-ges.fr EIML - ECOLE INTERNATIONALE DE MARKETING DU LUXE - PARIS
# comart-design.com Com'Art Design
# eductive.fr EDBS - Nantes
#  Euridis Business School - Campus de Paris - Saint Lazare
# eductive.fr EDBS - Toulouse
# toulouse-ort.asso.fr ORT Lyon
# espas-estice-icm.fr ESTICE - International Management
# iscom.fr ISCOM - Institut supérieur de communication et de publicité - Montpellier
# vatel.fr Vatel Campus les « Chartrons » Bordeaux
# iso.fr ISO - Institut Supérieur d'Optique Lyon
# iso.fr ISO - Institut Supérieur d'Optique Paris
# emineo-education.fr ISVM - Institut de Santé du Vivant et du Médico-social - Bordeaux
# isffel.fr ISFFEL - Saint Pol-de-Léon
# groupe-ipf.com IRIS - Ecole Supérieur d'informatique et de Numérique - Paris
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - PARIS
# iscom.fr ISCOM - Institut supérieur de communication et de publicité - Lyon
# iscom.fr ISCOM - Institut supérieur de communication et de publicité - Lille
# ecole-energietech.fr L'Ecole Energie Tech
# competences-developpement.fr SUP'DE COM - Lyon
# institutlyfe.com Institut Lyfe, Management en Arts Culinaires & Hôtellerie
# institut-g4.fr Institut G4 - Marseille
# audencia.com Audencia SciencesCom - MediaCampus
# competences-developpement.fr EPSI Grenoble
# ppa.fr PPA BUSINESS SCHOOL - PARIS
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Nantes
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Lille
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Bordeaux
# inseec.com SUP'DE COM - Bordeaux
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Amiens
# competences-developpement.fr SUP'DE COM - Grenoble
# epf.fr EPF - Troyes
# epf.fr EPF - Montpellier
# eimparis.com Ecole Internationale de Management de Paris
# ecole-ipssi.com IPSSI - Paris
# isme.fr ISME Nantes
# itecom-artdesign.com Itecom Art Design - Nice
# ipacfactory.com Ipac Bachelor Factory Angers
# ipacfactory.com Ipac Bachelor Factory de Lille
# ipacfactory.com Ipac Bachelor Factory Montpellier
# ipacfactory.com IPAC Bachelor Factory Paris-Ouest
# ipacfactory.com Ipac Bachelor Factory Paris Sud
# talisformation.com TALIS Bergerac
# h3campus.fr H3 Campus Poissy
# exchange-college.com EXCHANGE COLLEGE- Lille
# ecole-ipssi.com IPSSI - Lyon
# cogefi.com CFA Cogefi Formation
# ecole-ipssi.com IPSSI - Montpellier
# ecole-ipssi.com IPSSI - Nice
# figs-education.com ICL - L'école des Business Developers - Campus de Lille
# ifocop.fr CFA IFOCOP - Bordeaux/Bègles
# figs-education.com ICL - L'école des Business Developers - Campus de Montpellier
# ismac.fr ISMAC (Institut supérieur de management et de la communication)
# digital-college.fr Digital College - Nantes
# pigier.com Pigier Lille
# holbertonschool.com Holberton Thonon-les-Bains
# holbertonschool.com Holberton Bordeaux
# euridis.net Euridis Business School - Campus de Montpellier
# esct.fr ECOLE SUPERIEURE DE CONDUITE DE TRAVAUX (ESCT) - Strasbourg
# figs-education.com L’école internationale du management responsable - 3A- Campus Bordeaux
# purple-campus.com Purple Campus - Perpignan
# purple-campus.com Purple Campus - Montpellier
# purple-campus.com Purple Campus - Béziers
#  Purple Campus - Rodez
# reseau-ges.fr PPA Digital
# mba-esg.com MBA ESG
# ikigai-education.com Jump - Académie des Métiers du Sport et de l'E-Sport
# ecoris.com ECORIS - Lyon
# campus-espl.fr École Supérieure des Pays de Loire - Angers
# ppa.fr MBA Pôle Paris Alternance
# cordonbleu.edu Le Cordon Bleu Paris
# eductive.fr EFET CRÉA - PARIS
# ecole-de-savignac.com Ecole de Savignac
# kedgebs.com KEDGE Business School Marseille
# kedgebs.com KEDGE Business School Paris
# ferrandi-paris.fr FERRANDI Paris : Campus de Rennes
# ascencia-bs.com ASCENCIA Saint Quentin en Yvelines
# ascencia-bs.com ASCENCIA - Évry
# ascencia-bs.com ASCENCIA - Marne-la-Vallée
# ascencia-bs.com ASCENCIA - Paris La Défense
# orange.fr Ecole de Management de Normandie - Le Havre
# reseau-ges.fr ESIS Paris - Ecole Supérieure de l'Image et du Son
#  TALIS Périgueux
# ace-education.com AMOS - Ecole du Commerce du Sport - Paris
# talis-cc.com IFTE - IDF
# groupe-espi.fr Ecole Supérieure des Professions Immobilières - ESPI Bordeaux
# mydigitalschool.com MyDigitalSchool - Angers
# ief2i.fr Institut F2I
# epb.paris EPB - L’École de Préparation au BTS
# altea-bds.com Altéa Business & Digital School
# ecema.fr Ecole supérieure européenne de management en alternance - Saint Étienne
# isme.fr ISME La Rochelle
# studio-m.fr Studio MERCIER
# competences-developpement.fr WIS Montpellier
# mbway.com MBway - Bordeaux
# mbway.com MBway - Nantes
# mbway.com MBway - Paris Ouest
# mbway.com MBway - Strasbourg
# mbway.com Mbway - Toulouse
# groupe-gema.com ESI Business School - Paris
# talis-cc.com IFTE - IDF
# mydigitalschool.com MyDigitalSchool - Angers
# groupe-espi.fr Ecole Supérieure des Professions Immobilières - ESPI Bordeaux
# ief2i.fr Institut F2I
# winsportschool.com Win Sport School Toulouse
# winsportschool.com Win Sport School - Strasbourg
# mydigitalschool.com MyDigitalSchool - Nantes
# esg-sport.com ESG Sport - Paris
# figs-education.com L’école internationale du management responsable - 3A - Campus Lyon
# figs-education.com L’école internationale du management responsable - 3A - Campus Paris
# ecole-ipssi.com IPSSI - Saint-Quentin-en-Yvelines
# competences-developpement.fr WIS Paris
# competences-developpement.fr WIS Toulouse
# competences-developpement.fr WIS Grenoble
# winsportschool.com Win Sport School - Angers
# winsportschool.com Win Sport School - Lille
# winsportschool.com Win Sport School - Nancy
# winsportschool.com Win Sport School - Nice
# winsportschool.com Win Sport School - Nantes
# winsportschool.com Win Sport School - Paris Levallois
# winsportschool.com Win Sport School - Strasbourg
# winsportschool.com Win Sport School Toulouse
# mydigitalschool.com MyDigitalSchool - Nantes
# esg-sport.com ESG Sport - Paris
# figs-education.com L’école internationale du management responsable - 3A - Campus Lyon
# figs-education.com L’école internationale du management responsable - 3A - Campus Paris
# ecole-ipssi.com IPSSI - Saint-Quentin-en-Yvelines
# competences-developpement.fr WIS Paris
# competences-developpement.fr WIS Grenoble
# competences-developpement.fr WIS Toulouse
# escm-ecole.fr ESCM - Strasbourg
# winsportschool.com Win Sport School - Laval
# euridis.net Euridis Business School - Campus de Lille
# em-normandie.fr Ecole de Management de Normandie - Paris
# creapole.fr CREAPOLE ESDI
# ecam-rennes.fr ECAM Rennes - Louis de Broglie
# cpes.fr CPES - IPRESS
# cerfal.fr CFA CERFAL
# supdevinci.fr SUP DE VINCI - Paris
# pole-formation.net IFAG - Institut de formation aux affaires et à la gestion - Auxerre
# isipca-lafabrique.fr ISIPCA
# espas-estice-icm.fr ESPAS
# ille-et-vilaine.cci.fr Faculté Des Métiers - Rennes
# epmt.fr EPMT - École de Paris des Métiers de la Table
# competences-developpement.fr IEFT - Institut européen de formation au tourisme - Lyon
# letudiant.fr ESICAD - Ecole supérieure privée de commerce et gestion - Montpellier
# figs-education.com ILERI - L’Institut Libre des Relations Internationales et des Sciences Politiques - Lyon
# pole-formation.net ITII Bourgogne - Campus d'Auxerre
# ggeedu.fr ESGRH école supérieure de gestion des ressources humaines
# ihedrea.fr IHEDREA - L'école de l'Agri et de l'Agro Management - Paris
# idrac-bs.fr IDRAC Business School - Campus de Nantes
# mediaschool.eu ECS Paris - Ecole de communication
# esupcom.com ESUPCOM - ECOLE SUPERIEURE DE COMMUNICATION - LILLE
# talisformation.com TALIS Paris
# esupcom.com ESUPCOM - ECOLE SUPERIEURE DE COMMUNICATION - AIX-EN-PROVENCE
# lh.school Luxury Hotelschool Paris
# esarc-evolution.fr ESARC Toulouse
# studio-m.fr STUDIO M - Montpellier
# ecoris.com ECORIS - Chambéry
# emc.fr Ecole supérieure des métiers de l’image, du son et de la création 2D-3D
# gmail.com ECORIS - Annecy
# aforem.fr AFOREM Rennes
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Rennes
# maestris.com MAESTRIS BTS - REIMS
# ecema.fr Ecole supérieure européenne de management en alternance - Lyon
# competences-developpement.fr EPSI Toulouse
# esg.fr ESG Luxe - École de Marketing et de Management du Luxe à Paris
# competences-developpement.fr EPSI Rennes
# maestris.com MAESTRIS BTS - GRENOBLE
# figs-education.com L’école internationale du management responsable - 3A- Campus Toulouse
# edf.fr CFA des Métiers Des Énergies
# figs-education.com ILERI - L’Institut Libre des Relations Internationales et des Sciences Politiques - Paris
# efrei.fr Efrei- Ecole d'ingénieur - Informatique et technologies du numérique - Bordeaux
# 1984.school 1984 School of design
# ifcv.fr IFCV
# eductive.fr PPA SPORT - PARIS
# groupe-gema.com ESI Business School - Lyon
# euridis.net Euridis Business School - Campus de Bordeaux
# esg.fr ESG Tourisme
# livecampus.fr LiveCampus
# efab.fr EFAB IMMOBILIER - TOULON
#  Suptertiaire - Campus de Paris
# eductive.fr EFET CREA - REIMS
# esdm-formation.fr ESDM - École Nantaise du Développement Durable & de Management
# competences-developpement.fr EPSI Paris
# competences-developpement.fr EPSI Bordeaux
# pigier.com Ecole Pigier - Strasbourg
# pigier.com Ecole Pigier - Paris
# pigier.com Ecole Pigier - Nancy
# univ-lorraine.fr ENIM - Ecole nationale d'ingénieurs de Metz
# enc-nantes.fr ENC Nantes
# ecoletunon.com École Internationale Tunon - Montpellier
# collegedeparis.fr Eucléa Business School - Strasbourg
# mydigitalschool.com MyDigitalSchool - Montpellier
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - GRENOBLE
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - AIX-EN-PROVENCE
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - LYON
# ppa.fr PPA BUSINESS SCHOOL - AIX-EN-PROVENCE
# ppa.fr PPA BUSINESS SCHOOL - REIMS
# sciences-u.fr PPA BUSINESS SCHOOL - LYON
# maestris.com MAESTRIS BTS - TOULON
# eductive.fr EFET CREA - GRENOBLE
# maestris.com MAESTRIS BTS - AIX-EN-PROVENCE
# competences-developpement.fr WIS Rennes
# maestris.com MAESTRIS BTS - LYON
# alterneoecole.fr Alterneo - Paris
# mbway.com MBway - Paris Sud
# figs-education.com IET - L’Institut des métiers de l’Environnement et de la Transition écologique - Lyon
# figs-education.com IET - L’Institut des métiers de l’Environnement et de la Transition écologique - Nantes
# ecole-it.com Ecole IT - Campus de Valenciennes
#  Ecole IT - Campus d'Orléans
# supdevinci.fr SUP DE VINCI - Rennes
# maestris.com MAESTRIS BTS - PARIS
# reseau-ges.fr ICAN - Institut de création et d'animation numériques - LYON
# eductive.fr MODART INTERNATIONAL - LYON
# eductive.fr EDBS - LYON
# efab.fr EFAB IMMOBILIER - AIX-EN-PROVENCE
# efab.fr EFAB IMMOBILIER - REIMS
# reseau-ges.fr ICAN - Institut de création et d'animation numériques - PARIS
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - LILLE
# unicaen.fr IAE Caen - École Universitaire de Management
# gmail.com ICR - Institut catholique de Rennes
# competences-developpement.fr EPSI Toulouse
#  Narratiiv
# ifcv.fr IFCV
# eductive.fr PPA SPORT - PARIS
# esg.fr ESG Tourisme
# mbs-education.com MBS
# eductive.fr EFET CREA - REIMS
# hetic.fr HETIC, la grande école de la Tech et des métiers du digital
# groupe-esa.com ESA Paris (Ecole Supérieure des Agricultures)
# eductive.fr EFET CREA - TOULOUSE
# eductive.fr PPA SPORT - GRENOBLE
# ppa.fr PPA BUSINESS SCHOOL - TOULOUSE
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - LYON
# eductive.fr PPA SPORT - AIX
# eductive.fr PPA SPORT - LYON
# eductive.fr PPA SPORT - NANTES
# eductive.fr PPA SPORT - TOULOUSE
# eductive.fr MODART INTERNATIONAL - LILLE
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - NANTES
# reseau-ges.fr ICAN - Institut de création et d'animation numériques - LILLE
# emineo-education.fr FORMASUP Campus
# supdevinci.fr SUP DE VINCI - Rennes
# maestris.com MAESTRIS BTS - PARIS
# cy-ecolededesign.fr CY - Ecole de design
# cfa-numia.fr Centre de Formation d'Apprentis numiA
# ihedrea.fr IHEDREA - L'école de l'Agri et de l'Agro Management - Toulouse
# competences-developpement.fr IEFT - Institut européen de formation au tourisme - Nantes
# ecema.fr Ecole supérieure européenne de management en alternance - Clermont-Ferrand
# figs-education.com IGEFI BORDEAUX
# collegedeparis.fr Eucléa Business School - Metz
# efht.fr EFHT Paris
# pigier.com Ecole Pigier - Reims
# figs-education.com ICL - L'école des Business Developers - Campus de Nantes
# holbertonschool.com Holberton Lille
# holbertonschool.com Holberton Laval
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE - Toulon
# maestris.com MAESTRIS BTS - TOULOUSE
# rocket-school.com Rocket School - Paris
# ifams.fr IFAMS
# efab.fr EFAB IMMOBILIER - Toulouse
# gip-cei.com Ecole Supérieure des Technologies Industrielles Redon
# competences-developpement.fr WIS Arras
# digital-college.fr Digital College - Toulouse
# collegedeparis.fr Eucléa Business School - Mulhouse
# univ-amu.fr Ecole Dentaire Française
# ecoris.com ECORIS - Grenoble
# collegedeparis.fr Ecole Conte - Lyon
# collegedeparis.fr Ecole Conte - Toulouse
# ace-education.com ESDAC Paris
# dbs.school Digital Business School Nîmes
# mydigitalschool.com MyDigitalSchool - Nancy
# itecom-artdesign.com Itecom Art Design - Aix-en-Provence
# esad-dentaire.com ESAD école supérieure d'assistanat dentaire - Paris
# purple-campus.com Purple Campus - Tarbes
#  Purple Campus - Albi
# digital-college.fr Business Project College
# pigier.com Ecole Pigier - Montpellier
# esicad.com ESICAD - Ecole supérieure privée de commerce et gestion - Toulouse
# omneseducation.com Sup Career Paris - Omnes Education
# talis-bs.com Talis Bordeaux
# ispn.fr ISPN - Institut Supérieur Professionnel de Caen
# bellecour.fr Bellecour École, école de design, d’animation et de jeu vidéo à Lyon
# sportsmanagementschool.fr Sports Management School
# eemi.com EEMI - Ecole Européenne des Metiers de l'Internet - Paris
# letudiant.fr L’ECITV, La Grande École du Digital, du Web et de l’Audiovisuel en alternance - Paris
# reseau-ges.fr EIML - ECOLE INTERNATIONALE DE MARKETING DU LUXE - PARIS
# comart-design.com Com'Art Design
# ecole-multimedia.com L'École Multimédia
#  Euridis Business School - Campus de Paris - Saint Lazare
# cesacom.fr Cesacom Paris
# competences-developpement.fr SUP'DE COM - Nantes
# pigier.com Ecole Pigier - Marseille
# pigier.com Ecole Pigier - Aix-en-Provence
# mbway.com MBway - Angers
# mbway.com MBway - Lille
# mbway.com MBway - Montpellier
# kedgebs.com KEDGE Business School Bordeaux
# cesacom.fr Cesacom Lille
# h3hitema.fr H3 HITEMA
# itecom-artdesign.com Itecom Art Design - Paris
# institut-g4.fr Institut G4 - Lyon
# digital-campus.fr Digital Campus - Bordeaux
# supdeluxe.fr Sup de Luxe
# isifaplusvalues.com ISIFA Plus Values - Sud
# mediaschool.eu IEJ - Institut européen de journalisme
# isifaplusvalues.com ISIFA Plus Values - Ouest
# ifc.fr IFC - Loire
# reseau-cd.fr EPSI Lille
# competences-developpement.fr EPSI Grenoble
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Nantes
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Bordeaux
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Lille
# inseec.com SUP'DE COM - Bordeaux
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Amiens
# competences-developpement.fr SUP'DE COM - Grenoble
# epf.fr EPF - Troyes
# epf.fr EPF - Montpellier
# ecole-ipssi.com IPSSI - Paris
# eimparis.com Ecole Internationale de Management de Paris
# isme.fr ISME Nantes
# itecom-artdesign.com Itecom Art Design - Nice
# ipacfactory.com Ipac Bachelor Factory Angers
# ipacfactory.com Ipac Bachelor Factory de Lille
# ipacfactory.com IPAC Bachelor Factory Paris-Ouest
# ipacfactory.com Ipac Bachelor Factory Montpellier
# ipacfactory.com Ipac Bachelor Factory Paris Sud
# talisformation.com TALIS Bergerac
# h3campus.fr H3 Campus Poissy
# competences-developpement.fr WIS Lyon
# worldimpactsummit.com WIS Bordeaux
# competences-developpement.fr WIS Lille
# competences-developpement.fr WIS Nantes
# reseau-ges.fr PPA Digital
# sornas.fr EDTA SORNAS
# ikigai-education.com Jump - Académie des Métiers du Sport et de l'E-Sport
# studapart.com Lohanda
# gip-cei.com Institut IFALP
# ihecf.fr IHECF Paris Sud
# cesacom.fr Cesacom Le Mans
# figs-education.com IFAG - Institut de formation aux affaires et à la gestion - Arras
# cesacom.fr Cesacom Bordeaux
# ihecf.fr IHECF Lyon
# ecoris.com ECORIS Online
# studio-m.fr Studio M Strasbourg
# ipacfactory.com Ipac Bachelor Factory Bordeaux
# ecoletunon.com École Internationale Tunon - Angers
# esa-campus.fr ESA by H3 Campus Cholet
# isme.fr ISME Poitiers
# emineo-education.fr ISVM - Institut de Santé du Vivant et du Médico-social - Nantes
# ensao.fr ENSAO
# groupe-ics.fr Groupe ICS (Saint-Maur-des-Fossés)
# brest-opencampus.com HTBS - Angers
# brest-opencampus.com HTBS - Caen
# marseille-bs.fr Marseille Business School
# holbertonschool.com Holberton Rennes
# holbertonschool.com Holberton Dijon
# holbertonschool.com Holberton Fréjus
# esmd-droit.fr ESMD
# ecema.fr Ecole supérieure européenne de management en alternance - Grenoble
# i2-logistique.com I2L Metz
# ecema.fr Ecole supérieure européenne de management en alternance - Limoges
# ifa-formation.fr IFA Business School - Metz
# espub.org ESP - Ecole supérieure de publicité - Lille
# ifa-formation.fr IFA Business School - Nancy
# euridis.net Euridis Business School - Campus de Strasbourg
# mediaschool.eu GMS - Green Management School - Nice
# hautsdefrance.cci.fr LAHO Métropole Lilloise
# groupe-ipf.com ETS Ecole Européenne
# groupe-ipf.com Paris BTS
# groupe-ipf.com PSTC - Paris School of Tourism & Communication
# studio-m.fr STUDIO M - Nantes
# skale-france.com Skale Business School Antony
# ipacfactory.com Ipac Bachelor Factory de Lyon
# reseau-ges.fr ESIS Lille - Ecole Supérieure de l'Image et du Son
# reseau-ges.fr ECITV - Ecole du Web, du Digital et de l’Audiovisuel - Rennes
# reseau-ges.fr ESIS Lyon - Ecole Supérieure de l'Image et du Son
# eductive.fr ISA - l’institut supérieur d’audiovisuel - Toulouse
# groupe-espi.fr Ecole Supérieure des Professions Immobilières - ESPI Lille
# reseau-ges.fr ECITV - La Grande École du Digital, du Web et de l’Audiovisuel - Toulon
# groupe-espi.fr Ecole Supérieure des Professions Immobilières - ESPI Montpellier
# hermes.com L’École Hermès des savoir-faire - Pôle Paris-Val-de-Seine - Pantin
# hermes.com L’École Hermès des savoir-faire - Pôle Normandie - Val-de-Reuil - Louviers
# hermes.com L’École Hermès des savoir-faire - Pôle Paris-Val-de-Seine - Montereau
# hermes.com L’École Hermès des savoir-faire - Pôle de Franche-Comté - Allenjoie
# hermes.com L’École Hermès des savoir-faire - Pôle des Alpes - Fitilieu
# hermes.com L’École Hermès des savoir-faire - Pierre-Bénite
# hermes.com L’École Hermès des savoir-faire - Pôle Sud-Ouest - Marthon
# hermes.com L’École Hermès des savoir-faire - Pôle Sud-Ouest - Saint-Junien
# supdepub.fr Sup de Pub - Paris
# supdepub.fr Sup de Pub - Bordeaux
# hermes.com L’École Hermès des savoir-faire - Guyenne - Saint-Vincent-de-Paul
# supdepub.fr Sup de Pub - Lyon
# eductive.fr EFET CREA - BORDEAUX
#  Ecole IT - Campus d'Amiens
# reseau-ges.fr EIML - ECOLE INTERNATIONALE DE MARKETING DU LUXE - Reims
# reseau-ges.fr ICAN - Institut de création et d'animation numériques - BORDEAUX
# reseau-ges.fr ENGDE - ECOLE SUPERIEURE DE GESTION & D'EXPERTISE COMPTABLE - Aix-en-Provence
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - GRENOBLE
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - Aix-en-Provence
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - Nantes
# eductive.fr MODART INTERNATIONAL - BORDEAUX
# eductive.fr MODART INTERNATIONAL - Aix-en-Provence
# eductive.fr ISFJ - INSTITUT SUPERIEUR DE FORMATION AU JOURNALISME ET A LA COMMUNICATION DIGITALE - Reims
# maestris.com MAESTRIS BTS - BORDEAUX
# eductive.fr MODART INTERNATIONAL - REIMS
# pigier.com Ecole Pigier - Dijon
# hermes.com L’École Hermès des savoir-faire - Riom
# hermes.com L’École Hermès des savoir-faire - Val de Vence
# ille-et-vilaine.cci.fr Faculté Des Métiers - Lorient
# collegedeparis.fr Eucléa Business School - Thionville
# ihecf.fr IHECF Montpellier
# reseau-ges.fr EIML - ECOLE INTERNATIONALE DE MARKETING DU LUXE - Rennes
# isffel.fr ISFFEL - La Roche-Sur-Yon
# headn.fr HEADEN Lille
# headn.fr HEADEN Paris - La Défense
# headn.fr HEADEN Montpellier
# irfa-apisup.fr IRFA APISUP
# headn.fr HEADEN Lyon
# ecole-vidal.fr Ecoles Vidal Toulouse
# ecoleruffel.com RUFFEL
# pole-formation.net Pôle Formation 58-89 - Auxerre
#  DECODE
# ecosup-toulon.fr ECOSUP TOULON
# alaji.fr ALAJI Formations
# ifocop.fr CFA Rungis Alternance
# ecosup-campus.fr ECOSUP - Lille
# lecolededesign.com Ecole de design Nantes Atlantique
# idrac-bs.fr IDRAC Business School - Campus de Grenoble
# idrac-bs.fr IDRAC Business School - Campus de Montpellier
# esc-amiens.com ESC - Ecole supérieure de commerce d'Amiens
# ipag.fr IPAG Business School - Campus de Paris
# 3is.fr 3IS - 3IS Institut international de l'image et du son Paris
# ynov.com Ynov Création & Digital Design - Rennes
# suptertiaire.com Suptertiaire - Campus Lille
# digital-college.fr Digital College - Bordeaux
# letudiant.fr Digital College - Nice
# digischool.fr EXCHANGE COLLEGE- Toulouse
#  EXCHANGE COLLEGE- Strasbourg
#  Delta Business School
# eureka-education.fr Suptertiaire - Campus de Bordeaux
#  Institut de Gestion et de Commerce de Saint-Malo
# 3is.fr 3IS - 3IS Institut international de l'image et du son Paris
# ipag.fr IPAG Business School - Campus de Paris
# iso.fr ISO - Institut Supérieur d'Optique Toulouse
# pigier.com Ecole Pigier - Clermont Ferrand
# stmichel.fr Groupe Saint-Michel
# ac-nice.fr Lycée professionnel les Palmiers
# collegedeparis.fr ECAR Lille
# collegedeparis.fr ECOR Lille
# rocket-school.com Rocket School - Lille
# iso.fr ISO - Institut Supérieur d'Optique Grenoble
# rocket-school.com Rocket School - Bordeaux
# letudiant.fr Rocket School - Nantes
# rocket-school.com Rocket School - Marseille
# fgh-formation.fr FGH FORMATION
# esg.fr ESG - Ecole Supérieure de Gestion, commerce et finance - Rouen
# collegedeparis.fr Institut Supérieur de l’événement
# igensia.com IPI - École d'informatique Lyon
# gmail.com EIMA (Ecole Internationale des Métiers Audiovisuels)
# ingetis.com Ingetis Paris
# ynov.com Ynov Marketing & Communication - Bordeaux
# ynov.com Ynov Audiovisuel - Bordeaux
# ynov.com Ynov Création & Digital Design - Bordeaux
# ynov.com Ynov Audiovisuel - Lyon
# ynov.com Ynov Marketing & Communication - Lyon
# ynov.com Ynov Marketing & Communication - Aix en Provence
# ac-nice.fr LP A Escoffier
# ynov.com Ynov Création & Digital Design - Paris Ouest
# prepavesale.fr Prépa Vésale
# youschool.fr YouSchool
# lecolededesign.com Ecole de design Nantes Atlantique
# idrac-bs.fr IDRAC Business School - Campus de Grenoble
# idrac-bs.fr IDRAC Business School - Campus de Montpellier
# iriig.com IRIIG
# esc-amiens.com ESC - Ecole supérieure de commerce d'Amiens
# suptertiaire.com Suptertiaire - Campus de Lyon
#  Alternis Business School
# atelierdeschefs.com L'atelier des Chefs
# digital-college.fr Digital College - Strasbourg
# suptertiaire.com Suptertiaire - Campus Nantes
# yonne.cci.fr CCI Yonne Pôle Formation
# difcam.com CFA DIFCAM Sud-Ouest - Campus d'Albi
# difcam.com CFA DIFCAM Centre-Val-de-Loire - Campus de Tours
# exchange-college.com EXCHANGE COLLEGE- Lyon
# esg-immobilier.com ESG Immobilier - Bordeaux
# esg-immobilier.com ESG Immobilier - Montpellier
# rocket-school.com Rocket School - Lyon
# studio-m.fr Studio M - Rennes
# projet-cameleon.com Metaverse College
# ufip.eu UFIP Business School
# gmail.com Lycée H d'Estienne d'Orves
# ac-nice.fr LP Paul Valéry
# leparisien.fr LPO Lycée des métiers de l'hôtellerie et du tourisme Paul Augier
# leparisien.fr LGT Lycée du Parc Impérial
# letudiant.fr LPO Lycée polyvalent du Val d'Argens
# ac-nice.fr LGT Lycée Bristol
# leparisien.fr LGT Lycée Dumont d'Urville - Toulon
# ac-nice.fr Lycée Les Eucalyptus
# ynov.com Ynov informatique - Bordeaux
# ynov.com Ynov informatique - Aix en Provence
# ynov.com Ynov informatique - Toulouse
# iso.fr ISO - Institut Supérieur d'Optique Bordeaux
# iso.fr ISO - Institut Supérieur d'Optique Lille
# igensia.com ICD International Business School - Paris
# supdijon.fr SupDijon
# stan-sante.fr Stan Santé FormaSup - Nancy
# supexam-nantes.fr Supexam - Nantes
# skillandyou.com Ecole Chez Soi
# bersotformation.fr Bersot Formation
# studi.fr STUDI
# ynov.com Ynov informatique - Lyon
# cenef.fr Centre Européen de Formation
# ipacfactory.com IPAC Bachelor Factory Rennes
# ynov.com Ynov informatique - Nantes
# ifpc-formation.com IFPC - Ecole de Commerce & Communication
# ynov.com Ynov Audiovisuel - Strasbourg
# ynov.com Ynov Audiovisuel - Rouen
# digital-college.fr Digital College - Grenoble
# ynov.com Ynov Cybersécurité - Lyon
# ynov.com Ynov Cybersécurité - Montpellier
# ynov.com Ynov Cybersécurité - Nantes
# ynov.com Ynov Cybersécurité - Toulouse
# suptertiaire.com Suptertiaire - Campus d' Aix-en-Provence
# suptertiaire.com Suptertiaire - Campus de Strasbourg
# holbertonschool.com Holberton Rodez
# issat.cneap.fr Lycée ISSAT
# ifria-ouest.fr IFRIA Ouest via le Lycée Yves Thépôt
# univ-brest.fr ESIAB (École Supérieure d'Ingénieurs en Agroalimentaire de Bretagne Atlantique)
# rocket-school.com Rocket School - Nice
# rocket-school.com Rocket School - Montpellier
# ecole-ipssi.com IPSSI - Lille
# isjt.fr Institut Supérieur de Journalisme de Toulouse (ISJT)
# esao.eu ESAO (European School of Animal Ostheopathy)
# cours-agora.fr Cours Agora Montpellier
# cours-agora.fr Cours Agora Nîmes
# mail.com Aurlom BTS + - Nice
# athena-bs.fr Athena BS - Perpignan
# athena-bs.fr Athena BS - Montpellier
#  LAHO Artois-Douaisis - Lens
# fms-school.com FMS - L’école de commerce du Food Business - Lyon
# fms-school.com SMBS - L'école de commerce de la santé - Lyon
# rocket-school.com Rocket School - Toulouse
# formation-industries-pdl.fr IFRIA Ouest via Fab'Academy - UIMM La Roche-sur-Yon
# holbertonschool.com Holberton Caussade
# holbertonschool.com Holberton Sens
# groupefitec.fr Ecole PMN - Rennes
# igensia.com IGENSIA Alternance à Toulouse
# groupefitec.fr Ecole PMN - Lorient
# actifdigital.fr ESSIN
# groupefitec.fr Ecole PMN - Bordeaux
# lecolededesign.com Ecole de design Nantes Atlantique
# difcam.com CFA DIFCAM Centre Val de Loire - Agri Campus de Venours
# difcam.com CFA DIFCAM Centre Val de Loire - Campus de Nermont
# difcam.com CFA DIFCAM Méditerranée - Campus d'Avignon
# qwantic.co Qwantic
# ac-versailles.fr Lycée Paul Langevin
# uimm.com Pôle Formation UIMM Bretagne - Site de Lorient
# gmail.com Lycée Anne-Sophie Pic
# formation-industrie.bzh Pôle Formation UIMM Bretagne - Site de Plérin
# formation-industrie.bzh Pôle Formation UIMM Bretagne - Site de Vitré
#  École 18.06
# pole-formation.net Pôle Formation 58-89 - Nevers
# charente-maritime.cci.fr ACTORIA - Campus de Saintes
# ema.education École de Management Appliqué
# interval.fr SPS L’école du Sport - Tarbes
#  SPS L’école du Sport - Oloron-Sainte-Marie
# letudiant.fr SPS L'École du Sport - Bizanos
# aivancity.ai CCCLX
# alter-school.fr Alterschool
# garage404.com Garage404
# holbertonschool.com Holberton Mâcon
# skillandyou.com Skill and You
# graphland.fr Graph Land
# ace-education.com AMOS - Ecole du Commerce du Sport - Strasbourg
# lafabriqueduchocolat.fr CFA Académique - Besançon
#  CFAA - CFAA 79 antenne de Bressuire (du CFAA 79 Melle)Campus des Sicaudières
# digital-college.fr Digital College - Montpellier
#  CFAA 17 La Pichonnerie (au lycée Georges Desclaude)
# educagri.fr CFAA 16 - CFAA de la Charente L'Oisellerie d'Angoulême
# sophie-lecomte.com Ecole de Maquillage Artistique Sophie Lecomte
#  CFA supérieur de l'AFTEC - Chateaudun
# epitech.eu Epitech Digital School Bordeaux - La + Business des écoles Tech
#  CFA supérieur de l'AFTEC - Mignières
# media-squad.fr Ecole des praticiens du commerce international (Groupe ESSEC)
# irss.fr IRSS - Caen
# cespu.pt Cooperativa Da Ensino Superior Politécnico Universitário de Porto
# esme.fr ESME Paris Centre - L'école d'ingénieurs généraliste
#  Négociance Business School
# abilways.com EFE Formation
# univ-catholyon.fr ESDES - Lyon Business School
# lacomedie.fr Ecole de la Comédie de Saint-Etienne
#  Ecole de la Chambre Syndicale de la Couture Parisienne
# cinecreatis.net CinéCréatis - Montpellier
# lecnam.net CNAM Picardie - Amiens
# ecolescreatives.com ESMA - Ecole Supérieure des Métiers Artistiques - Nantes
# ecolescreatives.com ESMA - Ecole Supérieure des Métiers Artistiques - Montréal
# univ-corse.fr Paoli Tech - Ecole d'ingénieurs de l'Université de Corse, Université de Corse
# ecam-epmi.com ECAM-EPMI - Ecole d'ingénieurs généraliste
# chu-poitiers.fr Institut de Formation en Ergothérapie - Poitiers
# cesi.fr CESI - Nancy
# ecole-optique-lille.com EOL - Ecole d'Optique et de Lunetterie de Lille
# icart.fr ICART Lille - L'école du management de la culture et du marché de l'art
# cesi.fr CESI - Nanterre
# efap.com EFAP - L’école des nouveaux métiers de la communication
# efj.fr EFJ - L’école du nouveau journalisme
# brassart.fr BRASSART - L'école des métiers de la création
# elisa-aerospace.fr ELISA Aerospace - Saint-Quentin
# mbway.com MBway - Grand Genève
#  Pole IIID - Ecole d'infographie Pôle IIID
# leponyme.fr Ecole de théâtre l'Eponyme
# iscom.fr ISCOM - Institut supérieur de communication et de publicité - Bordeaux
# produits-laitiers.com Ecole d'industrie laitière - Poligny
#  Ecole d'esthétique Catherine Sertin
# next-u.fr Webtech Institute - Bordeaux
# enpc.fr Ecole des Ponts ParisTech
# orange.fr ETMH - Ecole des techniques du maquillage Christian Chauveau
# ecofac.fr ECOFAC - Rennes
# letudiant.fr L’Ecole Supérieure de l’Intelligence Numérique
# angouleme-emca.fr Ecole des métiers du cinéma d'animation - Groupe formation CIFOP - Ecole CCI Angoulême
# ecofac.fr ECOFAC - Nantes
# ecofac.fr ECOFAC - Angers
#  0292309C - Ecole des Mousses
# intradef.gouv.fr Ecole des Pupilles de l'air - Lycée de la Défense
# brassart.fr BRASSART Aix-en-Provence – L'école des métiers de la création
# brassart.fr BRASSART Grenoble – L'école des métiers de la création
# edu.heip.fr HEIP - Ecole des hautes études internationales et politiques
# ehess.fr EHESS-Marseille - Ecole des hautes études en sciences sociales - Marseille-GREQAM, Université Aix-Marseille II
# brassart.fr BRASSART Nantes – L'école des métiers de la création
# brassart.fr BRASSART Tours – L'école des métiers de la création
# ileps.fr ILEPS Cergy - Ecole des métiers du sport, Institut catholique de Paris
# ehesp.fr EHESP - Ecole des hautes études en santé publique
# brassart.fr BRASSART Caen – L'école des métiers de la création
# uxco.com BRASSART Montpellier – L'école des métiers de la création
# brassart.fr BRASSART Paris – L'école des métiers de la création
# brassart.fr BRASSART Toulouse – L'école des métiers de la création
# letudiant.fr Ecole des métiers du bâtiment Georges Bourachot (EMB)
# ecolescreatives.com EMA - Ecole des métiers artistiques
#  Ecole des beaux-arts de Bordeaux
# avocats-efacs.com Ecole des avocats Centre Sud
# esgi.fr ESGI - ECOLE SUPERIEURE DE GENIE INFORMATIQUE
# edago.fr Ecole des avocats du grand ouest
# versailles.fr Ecole des beaux-arts de Versailles
# edara.fr Ecole des avocats de la région Rhône-Alpes
# psycho-prat.fr Ecole de psychologues praticiens de Paris
# letudiant.fr ENAAI - Ecole d'enseignement aux arts appliqués et à l'image
# maestris.com MAESTRIS BTS
# reseau-ges.fr EFFICOM DIGITAL SCHOOL - LILLE
# efom.fr IFDMS - Institut de Formation des Métiers de la Santé et du Social - Fondation EFOM Boris Dolto
# reseau-ges.fr EFFICOM INFORMATIQUE
# uco.fr Institut de formation en éducation physique et sportive d'Angers - Université catholique de l'Ouest
# reseau-ges.fr EFFICOM DESIGN SCHOOL
#  Ecole d'art Maryse Eloy
# croix-rouge.fr Institut de formation d'auxilliaires de puériculture Croix-Rouge française
#  ECE École de Commerce Européenne - Lyon
# groupe-terrade.com Ecole de coiffure et esthétique
# colmar.fr EAP - Ecole d'arts plastiques
# croix-rouge.fr Ecole d'aides-soignants de la Croix-Rouge française
# gmail.com Ecole Darfeuille - Esthétique Coiffure
# isgroupe.com EAPS - Ecole d'Adaptation aux Professions du Soudage
# gmail.com Ecole Claude Mathieu
# mail.com Ecole Charles Dullin
#  ECE TECH - Ecole du numérique - Paris
# u-paris2.fr IDA - Institut de droit des affaires, Université Panthéon-Assas
# univ-lille.fr Institut de criminologie faculté sciences juridiques et politique, Université de Lille 2
# u-paris2.fr Institut de criminologie, Université Panthéon-Assas
# univ-lyon3.fr Université Jean Moulin - Lyon 3
# digital-campus.fr Digital Campus - Dakar
# univ-nantes.fr IAE Nantes Économie & Management
#  Info Tech - Aix-en-Provence
#  Info Tech - Rennes
#  Info Tech - Nantes
#  Info Tech - Angers
# supdev.fr e.sup vente
# supdepub.fr Sup de Film
# acfamultimedia.com Sup de Film- Angers
# ac-nantes.fr Sup de Film - Nantes
# iae-france.fr IAE - Institut d'administration des entreprises - Ecole universitaire du management, Université de Lille 1
# univ-tours.fr IAE - Institut d'administration des entreprises, Université de Tours Val de Loire
# univ-rouen.fr IAE - Institut d'administration des entreprises, Université de Rouen
#  École de Tourisme & d'Hôtellerie du Grand Trianon - Angers
#  SupdeMod
#  École de Tourisme & d'Hôtellerie du Grand Trianon - Rennes
# esup.fr e.sup vente - Angers
# tsm-education.fr Toulouse School Of Management
# grenoble-iae.fr IAE Grenoble - Institut d'administration des entreprises Grenoble, Université Grenoble Alpes (COMUE)
# ensup.eu e.sup vente - Nantes
# esg-sport.com ESG Sport - Bordeaux
# ecole-forma-study.fr Institut consulaire de formation
# icam.fr ICAM - Institut catholique d'arts et métiers - Bretagne
# esg-sport.com ESG Sport - Lyon
# esg-sport.com ESG Sport - Toulouse
# icam.fr ICAM - Institut catholique d'arts et métiers
# bioforce.org Institut Bioforce développement
#  Spot 3D - Aix-en-Provence
#  Digital Arts College - Aix-en-Provence
#  New York Ads - Aix-en-Provence
#  eSport University - Aix-en-Provence
# aixfilmlab.com Sup de Film - Aix-en-Provence
#  SupdeMod - Aix-en-Provence
#  École de Tourisme & d'Hôtellerie du Grand Trianon - Aix-en-Provence
# esiee-it.fr Coding Factory by ESIEE-IT - Paris
# itpa.fr ITPA Aix-en-Provence
# esiee-it.fr Coding Factory by ESIEE-IT - Cergy-Pontoise
# webitechparis.com Webitech
# nextformation.com NextFormation
# vitalopathie.org L'École Supérieure de Naturopathie
# comme-uneimage.com Le Quatre
# ipms.fr Institut Professionnel des Métiers du Sport
# letudiant.fr Institut Professionnel des Métiers du Sport - Tours
# ipms.fr Institut Professionnel des Métiers du Sport - Paris-Nanterre
# digischool.fr Institut Professionnel des Métiers du Sport - Nantes
# ispn.fr ISPN - Institut Supérieur Professionnel de Cherbourg
# my-bs.fr My Business School - My BS - Fréjus
# estp.fr ESTP Dijon
# ispn.fr ISPN - Institut Supérieur Professionnel
# figs-education.com ILERI - L’Institut Libre des Relations Internationales et des Sciences Politiques
# estp.fr ESTP Paris
# ecv.fr ECV Digital école du numérique et du web - Aix-en-Provence
# icam.fr ICAM - Institut catholique d'arts et métiers - Nantes
# ecv.fr ECV Digital école du numérique et du web - Lille (Campus MOLINEL)
# charlesquentin.cneap.fr Institut Charles Quentin
# yschools.fr SCBS - South Champagne Business School - Chaumont
# ibsm-mode.com IBSM - Mode & Marketing
# sports.gouv.fr Formation Club France
# iscod.fr Institut Supérieur des Compétences de Demain - Paris
# ingenieurs2000.com Ingénieurs 2000, Conservatoire national des arts et métiers, Université de Versailles Saint-Quentin-en-Yvelines, Université Paris-Est Marne-La-Vallée
# passerelle-esc.com Concours Passerelle
# passerelle-esc.com Passerelle Bachelor
# formations-naturopathe.eu ADNR Formations
#  LGTA - Institut agricole privé Saint-Christophe
# apecita.com Institut agricole Saint Eloi - LEAP
# univ-smb.fr INES Formation
#  Institut de Formation aux Affaires et à la Gestion
# studyrama.com INAsup - Pôle européen des sciences et métiers de l'image et du son
# formation-lac.com Campus du Lac : Tertiaire
# innoform.de INNOFORM
# theprogressfactory.fr The Nuum Factory
# xp-school.com XP School Paris - L'école des métiers du jeu vidéo et du gaming
# fondationlouisvuitton.fr IFORA Neuilly
# xp-school.com XP School Lyon - L'école des métiers du jeu vidéo et du gaming
# iesig.com IESIG
#  IFOM Vendée
# beauxartsdemarseille.fr CRR - Conservatoire à rayonnement régional Pierre Barbizet
# eap-grenoble.fr Ecole Supérieure Faugier
#  CRR - Conservatoire à rayonnement régional Maurice Ravel
# eurometropolemetz.eu CRR - Conservatoire à rayonnement régional Gabriel Pierné
# clermontmetropole.eu CRR - Conservatoire à rayonnement régional Emmanuel Chabrier
# grandnancy.eu Conservatoire régional du Grand Nancy (musique, danse, théâtre)
# editis.com Cours Renaissance
# gmail.com CRR - Conservatoire à rayonnement régional de Versailles
# gmail.com CRR - Conservatoire à rayonnement régional de Rueil-Malmaison
# paris.fr CRR - Conservatoire à rayonnement régional de Paris
# mairie-nantes.fr CRR - Conservatoire à rayonnement régional de Nantes
# letudiant.fr Cours Clapeyron
# perpignan-mediterranee.org CRR - Conservatoire à rayonnement régional de musique et de danse
# grenoble.fr CRR - Conservatoire à rayonnement régional de Grenoble
# reims.fr CRR - Conservatoire à rayonnement régional de Reims
# mairie-lille.fr CRR - Conservatoire à rayonnement régional de Lille
# ville-dijon.fr CRR - Conservatoire à rayonnement régional de Dijon
# conservatoire-lyon.fr CRR - Conservatoire à rayonnement régional de Lyon
# cergypontoise.fr CRR - Conservatoire à rayonnement régional de Cergy
#  CRR - Conservatoire à rayonnement régional - Toulon
#  CRR - Conservatoire à rayonnement régional - Nice
# gmail.com CRR - Conservatoire à rayonnement régional de Chambéry et des Pays de Savoie
# mairie-saint-maur.com CRR - Conservatoire à rayonnement régional de Saint-Maur
# cqamiens.fr CRR - Conservatoire à rayonnement régional - Amiens
# perpignan-mediterranee.org CRR - Conservatoire à Rayonnement Régional de Musique, de Danse et d'Art dramatique Perpignan Méditerranée
# ville.angers.fr CRR - Conservatoire à rayonnement régional - Angers
# perpignan-mediterranee.org CRR - Conservatoire à rayonnement régional de musique, danse et théâtre
# annecy.fr CRR - Conservatoire à rayonnement régional d'Annecy et des Pays de Savoie
# crr93.fr CRR - Conservatoire à rayonnement régional d'Aubervilliers
# seineouest.fr CRR - Conservatoire à rayonnement régional de Boulogne-Billancourt
# mairie-toulouse.fr CRR - Conservatoire à rayonnement régional - Toulouse
# mairie-bordeaux.fr CRR - Conservatoire à rayonnement régional Bordeaux Jacques Thibaud
# limoges.fr CRR - Conservatoire à rayonnement régional - Limoges
# montpellier.fr CRR - Conservatoire à rayonnement régional - Montepellier
# ville-tours.fr CRR - Conservatoire à rayonnement régional - Tours
# ville-rennes.fr CRR - Conservatoire à rayonnement régional - Rennes
# gmail.com CRR - Conservatoire à rayonnement régional
# caenlamer.fr CRR - Conservatoire à rayonnement régional - Caen
# aulnay-sous-bois.com CRD - Conservatoire à rayonnement départemental (musique et danse)
# aulnay-sous-bois.com CRD - Conservatoire à rayonnement départemental musique et danse
# valleesud.fr CRD - Conservatoire à rayonnement départemental musique - danse - théâtre
# wampark.fr CRD - Conservatoire à rayonnement départemental Eustache du Caurroy
# agglo-epinal.fr CRD - Conservatoire à rayonnement départemental Gautier d'Epinal
# gmail.com CRR - Conservatoire à rayonnement régional
# rouen.fr CRR - Conservatoire à rayonnement régional - Rouen
# grand-chatellerault.fr CRD - Conservatoire à rayonnement départemental du Pays Châtelleraudais
#  CRD - Conservatoire à rayonnement départemental Georges Guillot
#  CRD - Conservatoire à rayonnement départemental du maconnais Val de Saône
# blancmesnil.fr Conservatoire à rayonnement départemental du Blanc-Mesnil
# creuse.fr CRD - Conservatoire à rayonnement départemental Emile Goué
# mairie-villedavray.fr CRD - Conservatoire à rayonnement départemental de Ville-d'Avray
# gmail.com CRD - Conservatoire à rayonnement départemental de Versailles
#  CRD - Conservatoire à rayonnement départemental du pays de Romans
# agglo-agen.fr Conservatoire à rayonnement départemental du Lot et Garonne
#  CRD - Conservatoire à rayonnement départemental de Valence
#  Conservatoire à rayonnement départemental du Raincy
# agglo-pau.fr Conservatoire à rayonnement départemental des Pyrénées Atlantiques
# ville-romainville.fr CRD - Conservatoire à rayonnement départemental de Romainville
# saintnazaire.fr CRD - Conservatoire à rayonnement départemental de Saint-Nazaire
# alsace.cci.fr CCI CAMPUS - Strasbourg
#  CRD - Conservatoire à rayonnement départemental d'Orsay
# lacademiedesmetiersdart.com L'académie des Métiers d'Art
# facoparis.org FACO - Faculté libre de Droit
# 20minutes.fr Campus Academy - Aix-en-Provence
#  Campus Academy - Rennes
# ac-grenoble.fr Lycée Gaspard Monge
#  Faculté d'histoire et de géographie, Université Picardie Jules Verne Amiens
# ac-grenoble.fr Lycée Gambetta
#  Lycée Galilée
#  e.sup vente - Aix-en-Provence
# cauxseine.fr CRD - Conservatoire à rayonnement départemental de musique
#  CRD - Conservatoire à rayonnement départemental de l'Yonne
# grandorlyseinebievre.fr CRD - Conservatoire à rayonnement départemental de l'Hay-les-Roses
#  CRD - Conservatoire à rayonnement départemental de Nevers
# fresnes94.fr CRD - Conservatoire à rayonnement départemental de Fresnes
#  CRD - Conservatoire à rayonnement départemental de Gennevilliers
# crddordogne.com CRD - Conservatoire à rayonnement départemental de la Dordogne
#  CRD - Conservatoire à rayonnement départemental de Meudon
# grandorlyseinebievre.fr CRD - Conservatoire à rayonnement départemental de Cachan
# capi38.fr CRD - Conservatoire à rayonnement départemental de Bourgoin-Jallieu
# gpseo.fr CRD - Conservatoire à rayonnement départemental de Mantes-la-Jolie
# aixenprovencetourism.com CRR - Conservatoire à rayonnement régional Darius Milhaud
# gpseo.fr Conservatoire à rayonnement départemental
#  CRD - Conservatoire à rayonnement départemental
# ...
# enseignant.isaac-etoile.fr Centre de formation Ensemble scolaire Isaac de l'Etoile
# letudiant.fr Centre de formation d'apprentis universitaire
# esbanque.fr CFPB - Centre de formation de la profession bancaire
# formation-industries-auvergne.fr CFAI - Centre de formation d'apprentis de l'industrie d'Auvergne
# digischool.fr CFA CCI 04 - Centre de formation d'apprentis de la CCI des Alpes de Haute Provence
# normandie-univ.fr CFCB - Centre de formation aux carrières des bibliothèques, Université Toulouse II
# normandie-univ.fr CFCB - Centre de formation aux carrières des bibliothèques, Université de Caen Basse-Normandie
# inalco.fr INALCO CFI - Centre de communication et formation interculturelles, Institut national des langues et civilisations orientales
# mfr.asso.fr Centre de formation Bourgogne-Franche-Comté Antenne CFA MFR
# var.cci.fr Centre de formation CAPFORMA - CCIV - St Raphaël
# sorbonne-universite.fr CELSA - Paris Sorbonne
#  CEPPES - Centre d'éducation permanente et de promotion économique et sociale, Université de Valenciennes
# orange.fr Cafedanse - Centre aixois de formation à l'enseignement de la danse
# var.cci.fr Centre de formation - CAPFORMA - CCIV - Toulon
# mfr.asso.fr Centre de Formation aux Métiers de la Montagne
# societe.com C.COM Roubaix
# haute-savoie.cci.fr CCI Formation multimédia
# pigier.com Ecole Pigier - Tours
# carrel.fr Institut Carrel
#  CARTIF - Centre d'Apprentissage Régional des Techniques d'Impression et de Finition
# lyon-metropole.cci.fr EKLYA School of Business - Campus de Lyon
#  CCI Formation
#  CAP VERS - Nantes
# limoges.cci.fr Ecole Supérieure du Commerce et des Services de la CCI de Limoges et de la Haute-Vienne
# ccca-btp.fr CCI centre de formation de Perpignan
# carel.org CAREL - CAREL Centre audiovisuel de Royan pour l'étude des langues, Université de Poitiers
# digischool.fr CCI - CCI d'Annecy (Antenne CFA IMT)
# la-joliverie.com CECAM - Orléans
# cci28.fr Campus de la CCI d'Eure et Loir
# gmail.com CFA CM 86 - Campus des métiers St Benoit
# gmail.com CFA CM 79 - Campus des métiers de Parthenay
# gmail.com CFA CM 16 - Campus des métiers de Barbezieux
# gmail.com CFA CM 79 - Campus des métiers Henri Denoue Niort
# gmail.com CFA CM 17 - Campus des métiers La Rochelle
# gmail.com CFA CM 16 - Campus des métiers de Cognac
# btpcfa-poitou-charentes.fr CFA CMA 16 - Campus des métiers de Chasseneuil sur Bonnieure
# campus-pouille.com Campus de Pouillé-Angers
# btpcfa-hautsdefrance.fr BTP CFA Nord Pas de Calais
# btpcfa-hautsdefrance.fr BTP CFA Nord Pas de Calais
# biwsa.fr Bordeaux International Wine Institute
# lebelloy.com BTP CFA Le Belloy
# batimentcfanormandie.fr BTP-CFA Maurice Pierre VALETTE
# ecoles-conde.com Axe Sud - Marseille
# eslsca.fr INSAM - Groupe ESLSCA
# ac-limoges.fr Bâtiment CFA Limousin
# batimentcfanormandie.fr Bâtiment CFA Rouen Lanfry
# autograf.fr Autograf
# audencia.com AUDENCIA - Ecole de Management
#  Atelier théâtre Frédéric Jacquot
# artcena.fr Atelier théâtre d'aujourd'hui
#  Atelier d'expression théâtrale Radka Riaskova
#  ATA - Villeneuve d'Ascq
# atelier-chardon-savard.com Atelier Chardon Savard
# assisteo.ch Assisteo
# afbb.org AFBB - Association pour la formation de la biochimie et de la biologie
#  AMSNE - Association médico-sociale du Nord-Est
# paristech.fr ENSAM Arts et Métiers ParisTech
# ensam.eu ENSAM - Arts et Métiers ParisTech - Centre de Talence
# ensam.eu ENSAM Chambéry - Arts et Métiers ParisTech - Institut de Chambéry
# gmail.com Ateliers du Sudden
# asfo.fr ASFO BSB - Pau
# paristech.fr ENSAM - Arts et Métiers Paris Tech
#  Avant-scène école de maquillage artistique
# ensam.eu ENSAM - Arts et Métiers ParisTech - Centre de Châlons-en-Champagne
# ensam.eu ENSAM - Arts et Métiers ParisTech - Centre d'Angers
# ensam.eu ENSAM - Arts et Métiers ParisTech - Centre d'Aix-en-Provence
# ensam.eu ENSAM - Artrs et Métiers ParisTech - Centre de Cluny
#  Arobase
# avenirformation.com Avenir formation
# esec.fr ÉSEC Lyon – L’école des métiers du cinéma et de l’audiovisuel
# societe.com ARIS Formation - La Rochelle
# ecolejeantrubert.com Arc en Ciel - Ecole Jean Trubert
# artfx.fr ARTFX - Lille
# ensam.eu ENSAM - Arts et Métiers ParisTech - Centre de Metz
# ensam.eu ENSAM - Arts et Métiers ParisTech - Centre de Lille
# univ-tlse2.fr Antenne universitaire UFR langues, littératures et civilisations étrangères Toulouse II, Université Toulouse II
# univ-tlse2.fr Antenne universitaire UFR sciences, espaces et sociétés, Université Toulouse II
# univ-tlse2.fr Antenne universitaire UFR Histoire, arts et archéologie Toulouse II, Université Toulouse II
#  AQUITCOM
# univ-lyon1.fr Antenne IUFM Saint-Etienne, Université Claude Bernard - Lyon 1
# univ-tlse2.fr Antenne universitaire UFR histoire, arts et archéologie, Université Toulouse Montauban
#  Antenne IUFM Lyon, Université Claude Bernard - Lyon 1
# univ-pau.fr Antenne UFR lettres, langues et sciences humaines, Université Pau et Pays de l'Adour
# univ-orleans.fr ASUC - Antenne scientifique universitaire de Chartres, Université d'Orléans
# univ-orleans.fr Antenne scientifique universitaire de Bourges, Université d'Orléans
# apdhes.fr APDHES Centre Pierre Veaux
#  Antenne IUFM de la Dordogne, Université Bordeaux IV
#  Antenne IUFM du Lot et Garonne, Université Bordeaux IV
#  Antenne IUFM de Bordeaux-Caudéran, Université Bordeaux IV
#  Antenne IUFM des Landes, Université Bordeaux IV
# digischool.fr Antenne du département de lettres, langues et art (CUFR Jean-François Champollion)
#  Antenne rue Duverger du CFA de la Bourse du travail
# univ-jfc.fr Antenne du département de droit, économie, gestion (INU Jean-François Champollion), Institut National Universitaire Jean-François Champollion
#  Antenne IUFM des Pyrénées Atlantiques, Université Bordeaux IV
# uphf.fr IUT Maubeuge - Antenne de l'IUT de Valenciennes Maubeuge, Université de Valenciennes
# u-picardie.fr Antenne de Beauvais, Université Picardie Jules Verne Amiens
#  Antenne de l'UFR sciences et techniques, Université Pau et Pays de l'Adour
# univ-rouen.fr Antenne de l'UFR sciences et techniques de Mont Saint-Aignan, Université de Rouen
# cfbt-asso.com Antenne du CFA de la Bourse du travail (Marseille)
# univ-rouen.fr UFR de droit de l'université de Rouen - Antenne Campus d'Evreux, Université de Rouen
#  CCI - Antenne du CFA de la CCI 54
# formation-industries-lorraine.com CFAI - Antenne d'Henriville du CFAI de Moselle
#  Antenne du CFA Interconsulaire Méditerranée- Maison de l'entreprise
#  ISEM UM - Institut des sciences de l'entreprise et du management - antenne d'Orfeuillette, Université de Montpellier
# unilim.fr Antenne de la faculté des sciences et techniques de Limoges (Section STAPS), Université de Limoges
# letudiant.fr ISTV - Antenne de l'Institut des sciences et techniques de Valenciennes - Maubeuge, Université de Valenciennes
#  Antenne de la faculté des sciences du sport, Université Picardie Jules Verne Amiens
# univ-amu.fr UFR Droit et science politique - antenne de Marseille, Université d'Aix-Marseille
# univ-amu.fr FEG - Faculté Economie et gestion - site Canebière, Université d'Aix-Marseille
# eesc.fr CCI 54 - Antenne de Longwy du CFA de la CCI 54
#  Antenne de Metz du CFA Transport et Logistique AFT-IFTIM
# univ-amu.fr Pôle universitaire - antenne de Gap, Université d'Aix-Marseille
# univ-amu.fr Antenne de Gap de la faculté des sciences du sport de Luminy, Université Aix-Marseille II
# univ-angers.fr Antenne de Cholet - IUT d'Angers, Université d'Angers
# aup.edu AUP - American University of Paris
# univ-montp3.fr UPVM3 - Antenne de Béziers, Université Paul Valéry Montpellier 3
# asmm.fr ASMM - American school of modern music
# igensia.com The American Business School Paris
#  Altern'Sup ESC Chambéry Savoie
# emploi.gouv.fr Alternance formation
# educagri.fr Antenne de Digne-Carmejane du CFA Louis Giraud - site de Digne (CFPPA)
# formation-industries-lorraine.com CFAI - Antenne de Thaon-les-Vosges du CFAI de Maxéville
# educagri.fr Antenne du lycée agricole de Montbrison Précieux
#  CFAI - Antenne de Sainte-Marguerite du CFAI de Maxéville
# digischool.fr CFAI - Antenne de Bar-le-Duc du CFAI de Maxéville (54)
# perigueuxbusiness-school.com Alliance européenne - Périgueux
# demarchesadministratives.fr CCI 54 - Antenne de Blenod-les-Pont-à-Mousson de la CCI 54
# agroparistech.fr AgroParisTech Massy
# educagri.fr CFPPA - Antenne d'Aix-Valabre du CFA Louis Giraud - site de Marseille
# ac-strasbourg.fr Antenne d'Arles du CFA interconsulaire Méditerranée
# agroparistech.fr AgroParisTech ENGREF Nancy
# agr.fr AGR l'école de l'image
# educagri.fr CFPPA - Antenne CFPPA de Pixérécourt du CFA agricole de Meurthe-et-Moselle
# agrocampus-ouest.fr AgroCampus Ouest - Angers
# aftec.fr AFTEC - Caen
#  Agrham formation
# digischool.fr ACTOR'S SUD
# acfamultimedia.com ACFA - Multimédia - Montpellier
# digischool.fr ACTE NEUF pour la formation du comédien (Direction Brigitte Girardey)
# magenia.com Académie européenne de théâtre corporel - Studio Magénia
# aimg.fr GOLFY CLUB - Académie internationale des métiers du golf
# leparisien.fr Aliénor Esthétique
#  Académie Grandes Terres
# academiecharpentier.com Académie Charpentier
# app-reseau.eu ADES Atelier de pédagogie personnalisée
# aim.fr AIM - Hotel & Tourism Management Academy
# igensia.com Campus IGS Alternance - Toulouse
# ecole-multimedia.com Ecole Supérieure de Création et de Multimédia
# digischool.fr Institut Pour l'Expertise Management School
#  IFOPI - Ecole Supérieure Technique Privée
# ensiate.fr ENSIATE - Suresnes
# groupe-hema.com ISEAM - Institut Supérieur d'Etudes en Alternance du Management
# collegedeparis.fr Atelier Préparatoire Françoise Conté
# idrac-bs.fr EFHC Ecole Supérieure de Commerce International
#  RC Test
# cfa-insta.fr EFHC International
#  ESDM - École supérieure de design et de merchandising Groupe CEPRECO
# ebbs.fr EBBS BUSINESS SCHOOL
#  Groupe Medicis
# next-u.fr Ecole supérieure de commerce et d'Economie Numérique - Bordeaux
# mbs-education.com MBS - Médicis Business School
# ionis-group.com Sup'Internet
# iseg.fr ISEG Marketing & Communication School - Campus de Paris
# ipag.fr IPAG Business School - Campus de Nice
#  Atelier Albers
# ipacfactory.com Bachelor Open - Paris
# ynov.com Ynov informatique - Paris Ouest
# hellowork.com Diplomeo - Aide en orientation
# iseg.fr ISEG Marketing & Communication School - Campus de Nantes
# iseg.fr ISEG Marketing & Communication School - Campus de Strasbourg
# iseg.fr ISEG Marketing & Communication School - Campus de Bordeaux
# epitech.eu Epitech Nice - L'Ecole de l'excellence informatique
# epitech.eu Epitech Rennes - L'Ecole de l'excellence informatique
# epitech.eu Epitech Montpellier - L'Ecole de l'excellence informatique
#  Sup'Audio Paris
#  Sup'Audio Lyon
#  Sup'Audio Marseille
#  Sup'Audio Nancy
#  Sup'Audio Nantes
# competences-developpement.fr SUP'DE COM - Paris
# ifc.fr École supérieure de commerce et de management Wesford - Clermont Ferrand
# diderot-education.com Cours Diderot - Paris
# diderot-education.com Cours Diderot - Toulouse
# sciences-u.fr SciencesU Lyon
# mediaschool.eu SUPDEWEB Paris
# ggeedu.fr Web School Factory
# esarc-evolution.fr ESARC EVOLUTION
# ecofac.fr ECOFAC - Le Mans
# esg.fr ESG - Ecole Supérieure de Gestion, commerce et finance - Rennes
# igensia.com IGS-RH Paris
# igensia.com Institut du Management des Services Immobiliers - Paris
# igensia.com IGS-RH Toulouse
#  ESCEM Ecole de Management - Tours
# pigier.com Ecole Pigier Performance - Lyon
#  Events Management School
# idelca.fr IDELCA Business school
# wes-sup.fr WES' SUP Ecole Supérieure de Commerce et de Management
# pigier.com PIGIER
# isfac.fr ISFAC Institut Supérieur de Formation par Alternance et Continue
# omneseducation.com INSEEC Business School - Lyon
# omneseducation.com Institut des Hautes Etudes Economiques et Commerciales - Business School
# diderot-education.com Cours Diderot
# zenitude-groupe.com IPAC Ecole de Management
#  EJDG - Ecole de journalisme de Grenoble
# esup.fr ESUP-Saint Germain
#  CNPC SPORT
# stan-sante.fr Stan'Santé - Nancy
# univ-st-etienne.fr Telecom Saint Etienne, Université Jean Monnet Saint-Etienne
# ipesud-prepa.fr IPESUD Montpellier
# ipesud-prepa.fr IPESUD Nîmes
# ipesud-prepa.fr IPESUD
#  Objectif Concours Santé - Dijon
# chu-grenoble.fr Objectif Concours Santé - Grenoble
# australis.fr Objectif Concours Santé - Lyon
#  Objectif Concours Santé
# stan-sante.fr STAN'SANTE
# biomedal.fr CPES - Besançon Biomédal
# stan-sante.fr Stan'Santé - Metz
# stan-sante.fr Stan'Santé - Angers
# stan-sante.fr Stan'Santé - Saint Etienne
# letudiant.fr Cercle des Conférences Médicales
# capesup-paces.fr Cape Sup
#  Cercle des Conférences Médicales - Lyon Sud
# gmail.com Cape Sup - Lyon
# capesup-paces.fr Cape Sup - Grenoble
#  Cours Esquirol - Toulouse
# cours-acces.fr Cours Accès - Bordeaux
# edhec.edu EDHEC Business School
# ipesante.fr Stan - Supexam
# cada.fr Plus Values
# ipag.fr IPAG Business School
# ace-education.com AMOS - Ecole du Commerce du Sport
# gmail.com Cape Sup Droit - Nantes
#  Cape Sup Droit - Toulouse
#  Cape Sup Droit - Bordeaux
#  Cape Sup Droit - Montpellier
# gmail.com Cape Sup Droit - Nancy
# gmail.com Cape Sup Droit - Dijon
# esol-optique.fr ESOL Montpellier
# mbway.com MBway
# mbway.com MBway - Annecy
# mbway.com MBway - Caen
# mbway.com MBway - Rennes
# albarelle.fr Cours Galien - Reims
# albarelle.fr Cours Galien - Aix en Provence
# albarelle.fr Cours Galien - Amiens
# albarelle.fr Cours Galien - Bordeaux
# albarelle.fr Cours Galien - Brest
# albarelle.fr Cours Galien - Clermont Ferrand
# albarelle.fr Cours Galien - Dijon
# albarelle.fr Cours Galien - Grenoble
# albarelle.fr Cours Galien - Lille
# albarelle.fr Cours Galien - Marseille
# albarelle.fr Cours Galien - Montpellier
# albarelle.fr Cours Galien - Nantes
# albarelle.fr Cours Galien - Nice
# albarelle.fr Cours Galien - Rennes
# albarelle.fr Cours Galien - Saint Etienne
# albarelle.fr Cours Galien - Strasbourg
# albarelle.fr Cours Galien
# edu-sante.com PCMP - Amiens
# edu-sante.com MédiConcours - Marseille
# adonis-hotels.com Adonis - Aix en Provence
# cpes.fr Prépa Vidal - Toulouse
# groupe-adonis.fr Adonis - Toulouse
# groupe-adonis.fr Adonis - Bordeaux
# groupe-adonis.fr Adonis - Montpellier
# groupe-adonis.fr Adonis - Lyon
# groupe-adonis.fr Adonis - Lille
# solutions-marketing-internet.ca Adonis Concours
# u-paris.fr Sciences U - Paris
# skillandyou.com Cours Minerve
# concours-sup.fr Concours SUP
#  Cours PAVIOT - Nantes
# education.gouv.fr CPES
#  CPES - Paris Cours HATTEMER
#  CPES - Avignon Eurexia
#  CPES - Aix-en-Provence ESCAGI
#  CEPES - Lille IPAM
# formasup-campus.fr CPES - Bordeaux FORMASUP
#  CPES - Limoges FORMASUP
# ens-lyon.fr CPES - Lyon Forma
# univ-rennes.fr CPES - Rennes
# mairie-nantes.fr CPES - Nantes
#  CPES - Orléans Cité Formation
#  CPES Rouen Form'Avenir
#  Institut National de la Gemmologie - Paris
#  CPES - St-Quentin-en-Picardie IRETS
#  CPES - Strasbourg Ecole Grandjean
# studyrama.com IRFAMS
# cnfdi.com Centre National Privé de Formation à Distance
# adrar-formation.com ADRAR Formations
# ecole-eac.com EAC - Marché de l’art, Culture, Luxe - Lyon
# letudiant.fr Poly-Prépas
# ecole-eac.com EAC - Marché de l’art, Culture, Luxe
#  Institut National de la Gemmologie - Lyon
#  Poly-Prépas - Paris
#  Poly-Prépas - Lyon
# letudiant.fr Poly-Prépas - Lille
#  Poly-Prépas - Bordeaux
# ecv.fr ECV Creative School & Community
#  Institut National de la Gemmologie
# competences-developpement.fr EPSI
# ecv.fr ECV Creative School & Community - Lille
# em-normandie.fr EM Normandie
# cesi.fr CESI
# esce.fr ESCE - Ecole supérieure du commerce extérieur Paris
# esce.fr ESCE - Ecole supérieure du commerce extérieur Lyon
# cesi.fr CESI - Arras
# cesi.fr CESI - Bordeaux
# ynov.com Ynov informatique - Ingésup
# epitech.eu Epitech - L'Ecole de l'excellence informatique
# liste.parisnanterre.fr Université Paris Ouest Nanterre La Défense
# cesacom.fr CESACOM
# idrac-bs.fr IDRAC Business School - Campus de Bordeaux
# ipsa.fr IPSA - École d'ingénieurs de l'air, de l'espace et des mobilités
# adaforss.fr Association pour le Développement de l'Apprentissage dans les Professions Sanitaires et Sociales - Ile-de-France
# tbs-education.fr TBS Education - Paris
# tbs-education.fr TBS Education
# isefac.fr ISEFAC - L'école de l'événementiel, de la communication et du management
# esiea.fr ESIEA, ingénieur·e·s d’un numérique utile
# ieseg.fr IESEG School of Management
# cinecreatis.net CinéCréatis
# ecolescreatives.com ESMA - Ecole Supérieure des Métiers Artistiques
# ✅ File created with email patterns: sample.xlsx
