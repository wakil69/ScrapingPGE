# %% [markdown]
# # Scraping companies from Welcome to the jungle
#
# https://www.welcometothejungle.com/fr/companies?page=1&query=&aroundQuery=France&refinementList%5Boffices.country_code%5D%5B%5D=FR

# %% [markdown]
# ### Scraping Notes – *Welcome to the Jungle* (Companies)
#
# * **Base URL:**
#   `https://www.welcometothejungle.com/fr/companies?page=1&query=&aroundQuery=France&refinementList%5Boffices.country_code%5D%5B%5D=FR`
#   → To paginate, update the `page=` parameter.
#
# * **Companies List:**
#
#   * Container: `<ul data-testid="companies-search-search-results">`
#   * Each company entry: `<li data-testid="companies-search-search-results-list-item-wrapper">`
#
# * **Company Name:**
#
#   * Located inside:
#     `<div class="sc-brzPDJ sc-eXZHrJ ewyPqM">`
#
# * **Company Details Page:**
#
#   * Clicking the `<a />` link inside the company card (`<div class="sc-cvHfgK fWNrn">`) opens the company’s details page.
#   * The website link is located in:
#     `<p class="sc-izXThL kPYtCp sc-cVttbi dhUINZ wui-text">`
#     → Contains an `<a>` tag → extract the `href`.
#   * The company category is located in:
#     `<div data-testid="showcase-header-sector" />`

# %% [markdown]
# ## Librairies

# %%
import time
import pandas as pd
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# ## Configure Chrome with a real user agent

# %%
options = Options()
options.add_argument("--start-maximized")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

# Start the driver
driver = webdriver.Chrome(options=options)

def human_sleep(a=2, b=5):
    """Randomized sleep to simulate human behavior"""
    time.sleep(random.uniform(a, b))
    
def accept_country_banner(driver):
    """Click the country banner 'Stay' button if it appears."""
    try:
        stay_button = driver.find_element(By.CSS_SELECTOR, 'button[data-testid="country-banner-stay-button"]')
        stay_button.click()
        print("✅ Country banner dismissed")
        human_sleep(2, 3)
    except:
        # Banner not present
        pass

# %% [markdown]
# ## Find the company list

# %%
results = []

for page in range(1, 35):
    print(f"\n--- Scraping page {page} ---")
    url = f"https://www.welcometothejungle.com/fr/companies?page={page}&query=&aroundQuery=France&refinementList%5Boffices.country_code%5D%5B%5D=FR"
    driver.get(url)
    human_sleep(4, 7)
    accept_country_banner(driver)

    try:
        companies_list = driver.find_element(
            By.CSS_SELECTOR, 'ul[data-testid="companies-search-search-results"]'
        )
        companies = companies_list.find_elements(
            By.CSS_SELECTOR,
            'li[data-testid="companies-search-search-results-list-item-wrapper"]',
        )
    except:
        print(f"No companies found on page {page}")
        continue

    company_links = []

    # --- Stage 1: Collect all company names + their detail page URLs ---
    for idx, company in enumerate(companies):
        try:
            driver.execute_script("arguments[0].scrollIntoView(true);", company)
            human_sleep(1, 3)

            # Company name
            name_div = company.find_element(
                By.CSS_SELECTOR, "div.sc-brzPDJ.sc-eXZHrJ.ewyPqM"
            )
            company_name = name_div.text.strip()

            # Company detail page link
            link = company.find_element(By.CSS_SELECTOR, "div.sc-cvHfgK.fWNrn a")
            company_url = link.get_attribute("href")

            company_links.append({"name": company_name, "detail_page": company_url})

        except Exception as e:
            print(f"Error collecting company {idx}: {e}")
            continue

    # --- Stage 2: Visit each detail page and extract the website URL ---

    for company in company_links:
        try:
            driver.get(company["detail_page"])
            human_sleep(3, 6)

            # Extract external website link
            try:
                website_block = driver.find_element(
                    By.CSS_SELECTOR, 'a[data-testid="showcase-header-website-link"]'
                )
                website_url = website_block.get_attribute("href")
            except:
                website_url = None

            try:
                sector_div = driver.find_element(
                    By.CSS_SELECTOR, 'div[data-testid="showcase-header-sector"] p'
                )
                category = sector_div.text.strip()
            except:
                category = None

            results.append(
                {
                    "name": company["name"],
                    "detail_page": company["detail_page"],
                    "website": website_url,
                    "category": category,
                }
            )
            print(results[-1])

        except Exception as e:
            print(f"Error visiting {company['detail_page']}: {e}")
            continue
        
    df = pd.DataFrame(results)
    df.to_excel("scraped_companies.xlsx", index=False)
    print(f"💾 Progress saved after page {page} — total {len(results)} companies")

driver.quit()

print("Scraped companies:", results)
# Out:
# --- Scraping page 1 ---
# ✅ Country banner dismissed
# {'name': 'Renaissance Studio', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/renaissance-studio', 'website': 'https://www.rowads.app/', 'category': 'AdTech / MarTech, Intelligence artificielle / Machine Learning, Publicité'}
# {'name': 'Foxglove', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/foxglove', 'website': 'https://www.foxglove-partner.com/', 'category': 'Design, Digital, Digital Marketing / Data Marketing'}
# {'name': 'Horizon', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/orizon', 'website': None, 'category': 'Digital, Digital Marketing / Data Marketing, Publicité'}
# {'name': 'Planon', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/planon', 'website': 'https://planonsoftware.com/fr', 'category': 'IT / Digital, Logiciels, SaaS / Cloud Services'}
# {'name': 'Eurowind Energy', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/eurowindenergy', 'website': 'https://eurowindenergy.com/fr', 'category': 'Energie, Environnement / Développement durable'}
# {'name': 'Wyes', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wyes', 'website': 'https://www.wyes.fr/', 'category': 'Intelligence artificielle / Machine Learning, Objets connectés, Santé'}
# {'name': 'Heex Technologies', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/heex', 'website': 'https://heex.io/', 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}
# {'name': 'La Tête Dans Les Nuages', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/la-tete-dans-les-nuages-1', 'website': 'https://www.ltdln.com/', 'category': 'Aménagement / Design, Art de vivre, E-commerce'}
# {'name': 'MOBILITEAM', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mobiliteam', 'website': 'https://www.cacd.fr/', 'category': 'Aménagement / Design, Architecture, Bâtiment / Travaux publics'}
# {'name': 'PARIFEX', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/parifex', 'website': 'https://www.parifex.com/', 'category': "Bureau d'études et d'ingénierie, Mobilité"}
# {'name': 'OREVE', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/oreve', 'website': 'https://www.ortec-group.com/', 'category': 'Environnement / Développement durable, Mobilité'}
# {'name': "Centre National du cinéma et de l'Image animée", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cnc-fr', 'website': 'https://www.cnc.fr/', 'category': 'Cinéma, Musées / Institutions culturelles, Télévision / Production audiovisuelle'}
# {'name': 'Bacchus / Cérès', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bacchus-services', 'website': 'https://www.bacchus-services.com/', 'category': 'Boissons, Epicerie fine, Restauration'}
# {'name': 'Atelier Ticho', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/atelier-ticho', 'website': None, 'category': "Architecture, Bureau d'études et d'ingénierie, Bâtiment / Travaux publics"}
# {'name': 'Ville de Talence', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ville-de-talence', 'website': 'https://www.talence.fr/', 'category': 'Collectivités publiques et territoriales, Relations publiques, Ressources humaines'}
# {'name': 'Quadient', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/quadient', 'website': 'https://www.quadient.com/', 'category': 'IT / Digital, Logiciels'}
# {'name': "Ministère de l'Agriculture et de la Souveraineté alimentaire", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ministere-de-l-agriculture-et-de-la-souveraine', 'website': 'https://www.agriculture.gouv.fr/', 'category': 'Administration publique'}
# {'name': 'Delos', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/delos', 'website': None, 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}
# {'name': 'Phagos', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/phagos-1', 'website': 'https://www.phagos.org/', 'category': 'Intelligence artificielle / Machine Learning, Pharmaceutique / Biotechnologique, Santé'}
# {'name': 'Plum', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/plum-kitchen', 'website': 'https://www.plum-living.com/', 'category': 'Aménagement / Design'}
# {'name': 'SVP', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/svp', 'website': None, 'category': "Accompagnement d'entreprises"}
# {'name': 'ALADINOO GROUP', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/aladinoo-group', 'website': 'https://aladinoogroup.com/', 'category': 'Distribution sélective, Evénementiel, Luxe'}
# {'name': 'PUR', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/pur', 'website': 'https://www.pur.co/', 'category': 'Environnement / Développement durable, SocialTech / GreenTech, Supply Chain'}
# {'name': 'Sigma Nova', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/sigma-nova', 'website': 'https://www.sigmanova.ai/', 'category': 'Intelligence artificielle / Machine Learning'}
# {'name': "Electricité d'Azur", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/electricitedazur-fr', 'website': 'https://www.electricitedazur.fr/', 'category': "Bureau d'études et d'ingénierie, Energie, Environnement / Développement durable"}
# {'name': 'GTF', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/gtf', 'website': 'https://www.gtf.fr/', 'category': 'Immobilier commercial, Immobilier particulier'}
# {'name': 'Innovie', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/innovie', 'website': 'https://www.innovie.fr/', 'category': 'Assurance, FinTech / InsurTech'}
# {'name': 'abondance experience', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/abondance', 'website': None, 'category': 'Evénementiel, Luxe, Marketing / Communication'}
# {'name': 'Kaeser Compresseurs France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/kaeser-compresseurs-france', 'website': 'https://fr.kaeser.com/', 'category': 'Bâtiment / Travaux publics, Ingénieries Spécialisées, Métallurgie'}
# {'name': 'off-campus', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/off-campus', 'website': 'https://www.offcampus.fr/', 'category': 'Education, Musées / Institutions culturelles, Restauration'}
# 💾 Progress saved after page 1 — total 30 companies
#
# --- Scraping page 2 ---
# {'name': 'Espérance banlieues', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/esperance-banlieues', 'website': 'https://www.esperancebanlieues.org/', 'category': 'Association, Education'}
# {'name': 'Collectif Cordial - OSCO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/collectif-cordial-osco', 'website': None, 'category': 'Agroalimentaire / Nutrition animale, Boissons, FoodTech'}
# {'name': 'TotalEnergies Marketing Digital Solutions', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/totalenergies-marketing-digital-solutions', 'website': 'https://tmds.io/', 'category': "Bureau d'études et d'ingénierie, Energie, SaaS / Cloud Services"}
# {'name': 'Calixys', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/calixys-1', 'website': 'https://www.calixys.com/', 'category': 'Logiciels'}
# {'name': 'SKYNOPY', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/skynopy', 'website': 'https://www.skynopy.com/', 'category': 'Aéronautique / Spatiale, Logiciels'}
# {'name': 'Datawords', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/datawords', 'website': 'http://datawords.com/', 'category': 'AdTech / MarTech, Digital, Marketing / Communication'}
# {'name': 'Mirabelle', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mirabelle', 'website': 'https://www.mirabelle.fr/', 'category': 'Assurance, FinTech / InsurTech, Immobilier particulier'}
# {'name': '10%', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/10', 'website': 'https://www.10pourcent.fr/', 'category': 'Application mobile, Digital Marketing / Data Marketing, Grande consommation'}
# {'name': 'Alphaguard', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/alphaguard-antler-portfolio', 'website': 'https://www.alphaguard.ai/', 'category': 'FinTech / InsurTech, Intelligence artificielle / Machine Learning, SaaS / Cloud Services'}
# {'name': 'Edumapper', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/edumapper', 'website': 'https://www.edumapper.com/', 'category': 'EdTech, Education, Formation'}
# {'name': 'IRIS Interactive', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/iris-interactive', 'website': 'https://www.iris-interactive.fr/', 'category': 'Digital, Digital Marketing / Data Marketing'}
# {'name': 'AÉSIO mutuelle', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/aesio-mutuelle', 'website': 'https://www.aesio.fr/', 'category': 'Assurance, Banque, Finance'}
# {'name': 'Naval Group [FR]', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/naval-group-fr', 'website': 'https://www.naval-group.com/', 'category': "Bureau d'études et d'ingénierie, Digital, Métallurgie"}
# {'name': 'AmazingContent', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/amazing-content', 'website': 'https://www.amazingcontent.io/', 'category': 'Application mobile, Marketing / Communication, SaaS / Cloud Services'}
# {'name': 'Passage Du Désir', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/passage-du-desir', 'website': 'https://www.passagedudesir.fr/', 'category': 'Distribution sélective, E-commerce'}
# {'name': 'Raidium', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/raidium', 'website': None, 'category': 'Intelligence artificielle / Machine Learning, Logiciels, Santé'}
# {'name': 'Capfinances', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/capfinances', 'website': 'https://capfinances.fr/', 'category': 'Assurance, Finance'}
# {'name': 'Dashlane', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dashlane', 'website': 'https://www.dashlane.com/en', 'category': 'Application mobile, Cybersécurité'}
# {'name': 'CJF Expertise & Stratégie', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cjf', 'website': 'https://www.cjf.eu/', 'category': "Accompagnement d'entreprises, Expertise comptable, Stratégie"}
# {'name': 'CEV GROUP', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cev-group', 'website': None, 'category': 'AdTech / MarTech, Digital Marketing / Data Marketing, E-commerce'}
# {'name': 'Nolej', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/nolej-1', 'website': 'https://www.nolej.io/', 'category': 'Application mobile, E-commerce, EdTech'}
# {'name': 'Direction interministérielle du numérique (DINUM) – Service du Premier ministre', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dinum', 'website': 'https://www.numerique.gouv.fr/', 'category': 'Administration publique'}
# {'name': 'Frénésie', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/frenesie', 'website': 'https://www.frenesie.com/', 'category': 'Digital, Evénementiel, Marketing / Communication, Publicité'}
# {'name': 'Ezus', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ezus', 'website': 'https://www.ezus.io/', 'category': 'Logiciels, SaaS / Cloud Services, Tourisme'}
# {'name': 'Crowe HAF', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/crowe-haf', 'website': 'https://www.crowe-haf.fr/', 'category': 'Audit, Finance, Transaction Services'}
# {'name': 'Altitude', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/groupe-altitude', 'website': 'https://www.groupe-altitude.com/', 'category': 'Automobile, Mobilité'}
# {'name': 'BlueLink', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bluelink', 'website': 'https://www.bluelinkservices.com/', 'category': "Accompagnement d'entreprises"}
# {'name': 'BORYL', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/boryl', 'website': 'https://www.boryl.io/', 'category': 'AdTech / MarTech, Digital, Digital Marketing / Data Marketing'}
# {'name': 'MYCOPHYTO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mycophyto', 'website': 'https://www.mycophyto.fr/', 'category': 'Environnement / Développement durable, Pharmaceutique / Biotechnologique, SocialTech / GreenTech'}
# {'name': 'LightOn', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/lighton-1', 'website': 'https://www.lighton.ai/', 'category': 'Intelligence artificielle / Machine Learning, SaaS / Cloud Services'}
# 💾 Progress saved after page 2 — total 60 companies
#
# --- Scraping page 3 ---
# {'name': 'Dentons', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dentons-2', 'website': 'https://www.dentons.com/', 'category': 'Architecture, Coworking, Service juridique'}
# {'name': 'XEILOS TRADING', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/xeilos-trading', 'website': 'https://www.xeilos.fr/', 'category': 'Finance, Formation, Recrutement'}
# {'name': 'Federation Studios', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/federation-studios', 'website': 'https://federationstudios.com/', 'category': 'Cinéma, Média, Télévision / Production audiovisuelle'}
# {'name': 'Contestio', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/contestio-fr', 'website': None, 'category': 'AdTech / MarTech'}
# {'name': 'BPCE Solutions informatiques', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bpce-solutions-informatiques', 'website': 'https://www.bpce-si.fr/', 'category': 'Banque, FinTech / InsurTech, IT / Digital'}
# {'name': 'Monetech', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/monetech', 'website': 'https://www.monetech.fr/', 'category': "Bureau d'études et d'ingénierie, IT / Digital, Mobilité"}
# {'name': 'Bleu', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bleu', 'website': 'https://www.bleucloud.fr/', 'category': 'Cybersécurité, IT / Digital, SaaS / Cloud Services'}
# {'name': 'SASU FNCCR (ACTEE)', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/actee', 'website': 'https://programme-cee-actee.fr/', 'category': 'Collectivités publiques et territoriales, Energie, Ingénieries Spécialisées'}
# {'name': 'Agence XPLR', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/agence-xplr', 'website': None, 'category': 'Digital, E-commerce, Marketing / Communication'}
# {'name': 'SoPost', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/sopost', 'website': 'https://sopost.com/', 'category': 'AdTech / MarTech, SaaS / Cloud Services'}
# {'name': 'Johnston Circular', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/johnston-circular', 'website': None, 'category': 'Environnement / Développement durable, Stratégie, Transformation'}
# {'name': 'Enioka Conseil', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/enioka', 'website': 'https://consulting.enioka.com/', 'category': 'IT / Digital, Logiciels, SaaS / Cloud Services'}
# {'name': 'Cinq-Cinq', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/5-cinq-fr', 'website': 'https://www.5-cinq.com/', 'category': "Architecture, Bureau d'études et d'ingénierie"}
# {'name': 'Overlayer', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/presencedoc', 'website': 'https://www.overlayer.ai/', 'category': 'Logiciels'}
# {'name': 'DiliTrust', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dilitrust', 'website': 'https://www.dilitrust.com/', 'category': 'Logiciels, SaaS / Cloud Services, Service juridique'}
# {'name': 'HRC Group', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/hrc-consulting-it', 'website': 'https://hrc-group.fr/', 'category': 'IT / Digital, Supply Chain'}
# {'name': 'Prosolia Energy', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/prosolia', 'website': 'https://www.prosoliaenergy.com/', 'category': 'Architecture, Energie, SocialTech / GreenTech'}
# {'name': 'Carlo', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/carlo', 'website': 'https://www.carloapp.com/', 'category': 'Application mobile, E-commerce, FinTech / InsurTech'}
# {'name': 'matterz. (WIZBII & obendy®)', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/matterz', 'website': 'https://www.matterz.group/', 'category': 'IT / Digital, SaaS / Cloud Services'}
# {'name': 'Anthony Garçon', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/anthony-garcon', 'website': None, 'category': 'Mode'}
# {'name': 'RealTimeSeismic', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/realtimeseismic', 'website': 'https://realtimeseismic.com/', 'category': "Bureau d'études et d'ingénierie, Energie, Environnement / Développement durable"}
# {'name': 'INTELCIA IT SOLUTIONS', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/intelcia', 'website': 'https://www.intelcia.com/fr/it-solutions', 'category': 'AdTech / MarTech, E-commerce, IT / Digital'}
# {'name': 'Daisy', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/daisy', 'website': None, 'category': 'Logiciels, Loisirs, SaaS / Cloud Services'}
# {'name': 'June Marketing', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/june-marketing', 'website': 'https://www.junemarketing.fr/', 'category': 'AdTech / MarTech, Digital, Marketing / Communication'}
# {'name': 'Valeco', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/valeco', 'website': 'https://www.groupevaleco.com/', 'category': 'Energie'}
# {'name': 'Delabie [FR]', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/delabie-fr', 'website': 'https://www.delabie.fr/', 'category': 'Distribution sélective, Environnement / Développement durable, Métallurgie'}
# {'name': 'Liberkeys', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/liberkeys', 'website': 'https://www.liberkeys.com/', 'category': 'Digital, Immobilier particulier, Transformation'}
# {'name': 'Selvitys', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/selvitys', 'website': 'https://www.selvitys.fr/', 'category': 'IT / Digital, Logiciels, SaaS / Cloud Services'}
# {'name': 'agencegust.com', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/agencegust-com', 'website': 'https://www.agencegust.com/', 'category': 'Digital, Marketing / Communication, Publicité'}
# {'name': '2tonnes', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/2tonnes', 'website': None, 'category': 'Environnement / Développement durable, Formation, SocialTech / GreenTech'}
# 💾 Progress saved after page 3 — total 90 companies
#
# --- Scraping page 4 ---
# {'name': 'Agence Superchouette', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/agence-superchouette', 'website': None, 'category': 'Design, Digital, Marketing / Communication'}
# {'name': 'Rewind', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/rewind', 'website': 'https://www.pro.rewindstories.fr/', 'category': 'Intelligence artificielle / Machine Learning, Logiciels, Tourisme'}
# {'name': "Ministère de l'Intérieur", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ministere-de-l-interieur', 'website': 'https://www.interieur.gouv.fr/ministere/metiers-du-ministere/je-veux-devenir-agent-public', 'category': 'Administration publique'}
# {'name': 'Rofim', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/rofim', 'website': 'https://www.rofim.fr/', 'category': 'Application mobile, SaaS / Cloud Services, Santé'}
# {'name': 'Terraillon', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/terraillon', 'website': 'https://www.terraillon.fr/', 'category': 'Electronique / Télécommunications, Grande consommation, Objets connectés'}
# {'name': 'CLARITY', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/clarity', 'website': 'http://www.clarity.consulting/', 'category': 'IT / Digital, Organisation / Management, Transformation'}
# {'name': 'Banque Delubac & Cie', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/delubac', 'website': 'https://www.delubac.com/', 'category': 'Banque, Finance'}
# {'name': 'Edumiam', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/edumiam', 'website': 'https://www.edumiam.com/', 'category': 'Application mobile, EdTech, Education'}
# {'name': 'SAFILO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/safilo', 'website': 'https://www.safilo.com/', 'category': 'Distribution sélective, Luxe, Mode'}
# {'name': 'Eficia', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/eficia-1', 'website': 'https://eficia.com/fr', 'category': 'Energie, Environnement / Développement durable, Logiciels'}
# {'name': 'Ladrome Laboratoire', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ladrome-laboratoire', 'website': 'https://ladrome.bio/', 'category': 'Cosmétique, Pharmaceutique / Biotechnologique, Santé'}
# {'name': 'WPP', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wpp', 'website': 'https://www.wpp.com/fr-fr/about', 'category': 'Digital, Marketing / Communication, Publicité'}
# {'name': 'Vulcain Engineering Group', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/vulcainengineering', 'website': 'https://www.vulcain-eng.com/', 'category': 'Energie, Ferroviaire, Ingénieries Spécialisées, Mobilité'}
# {'name': 'TREEWATER', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/treewater', 'website': 'https://www.treewater.fr/', 'category': "Bureau d'études et d'ingénierie, Energie, Environnement / Développement durable"}
# {'name': 'FORMEZVOO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/formezvoo', 'website': 'http://www.formezvoo.com/', 'category': "Accompagnement d'entreprises, Education"}
# {'name': 'Kraken', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/kraken', 'website': 'https://www.kraken.tech/', 'category': 'Environnement / Développement durable, SaaS / Cloud Services'}
# {'name': 'OpenClimat', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/openclimat', 'website': 'https://www.openclimat.com/', 'category': "Accompagnement d'entreprises, Environnement / Développement durable, SaaS / Cloud Services"}
# {'name': 'Dalma', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dalma', 'website': 'https://www.dalma.co/', 'category': 'Application mobile, Assurance'}
# {'name': 'Dubernard', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dubernard', 'website': 'https://www.dubernard.fr/', 'category': 'Bâtiment / Travaux publics, Métallurgie'}
# {'name': 'TOLEDE GROUPE & ASSOCIES', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/tolede-groupe-associes', 'website': 'https://www.tolede-groupe.com/', 'category': 'Assurance, Loisirs, Tourisme'}
# {'name': 'Mistral Ai', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mistral-ai', 'website': 'https://www.mistral.ai/', 'category': 'IT / Digital, Intelligence artificielle / Machine Learning, SaaS / Cloud Services'}
# {'name': 'YAY', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/yay', 'website': 'https://yay.paris/', 'category': 'Joaillerie'}
# {'name': 'Novetude Santé', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/novetude-sante', 'website': 'https://www.novetude.com/', 'category': 'EdTech, Education, Santé'}
# {'name': 'Waste Marketplace', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/waste-marketplace', 'website': 'https://www.wastemarketplace.fr/', 'category': 'Bâtiment / Travaux publics, Environnement / Développement durable, SaaS / Cloud Services'}
# {'name': 'Nabla', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/nabla', 'website': 'https://www.nabla.com/', 'category': 'Big Data, Intelligence artificielle / Machine Learning, Santé'}
# {'name': 'eMyosound', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/emyosound', 'website': 'https://www.emyosound.com/', 'category': 'Ingénieries Spécialisées, Intelligence artificielle / Machine Learning, Logiciels'}
# {'name': 'Edenred', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/edenred-holding', 'website': 'https://www.edenred.com/', 'category': 'FinTech / InsurTech'}
# {'name': 'Excellence Academy', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/excellence-academy', 'website': 'https://www.excellence-academy.fr/', 'category': 'EdTech, Education, Formation'}
# {'name': 'JTI France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/groupe-jti', 'website': 'https://www.jti.com/', 'category': 'Grande consommation'}
# {'name': 'IDRIS (CNRS)', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/idris-cnrs', 'website': 'http://www.idris.fr/', 'category': 'Administration scolaire et universitaire, EdTech, Intelligence artificielle / Machine Learning'}
# 💾 Progress saved after page 4 — total 120 companies
#
# --- Scraping page 5 ---
# {'name': 'Matsuri', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/matsuri', 'website': 'https://www.matsuri.fr/', 'category': 'Restauration'}
# {'name': 'Deck & Donohue', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/deck-donohue', 'website': 'https://deck-donohue.com/', 'category': 'Artisanat de bouche, Boissons, Epicerie fine'}
# {'name': 'Entrepreneurs.com', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/entrepreneurs.com', 'website': 'https://entrepreneurs.com/', 'category': "Accompagnement d'entreprises, Transformation"}
# {'name': 'Ed AI', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ed-ai', 'website': 'https://www.ed.ai/', 'category': 'EdTech, Education, Intelligence artificielle / Machine Learning'}
# {'name': 'ACD', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/acd', 'website': 'https://www.acd-groupe.fr/', 'category': "Bureau d'études et d'ingénierie, Expertise comptable, IT / Digital"}
# {'name': 'ADPED94', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/adped94', 'website': None, 'category': 'Association'}
# {'name': 'Enrise', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/enrise-1', 'website': 'https://www.enrise.fr/', 'category': 'Energie, Environnement / Développement durable, SocialTech / GreenTech'}
# {'name': 'Crédit Mutuel Alliance Fédérale', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/credit-mutuel-alliance-federale', 'website': None, 'category': ''}
# {'name': "L'Automobile Club de l'Ouest", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/automobile-club-de-l-ouest', 'website': 'https://www.lemans.org/', 'category': 'Association, Loisirs'}
# {'name': 'Rewake', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/rewake-1', 'website': 'https://rewake.fr/', 'category': 'E-commerce, Environnement / Développement durable, Pharmaceutique / Biotechnologique'}
# {'name': 'Piana', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/piana', 'website': 'https://www.getpiana.com/', 'category': 'FinTech / InsurTech, SaaS / Cloud Services'}
# {'name': 'Bien Sûr', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/gilbert', 'website': 'https://www.gilbert.paris/', 'category': 'Coworking, Immobilier commercial, Immobilier particulier'}
# {'name': 'TAOS', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/taos-re-start', 'website': 'https://taos.paris/', 'category': 'Aménagement / Design, Architecture'}
# {'name': 'Flow Line Integration', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/flow-line-integration-1', 'website': 'https://www.flowlineintegration.com/', 'category': 'IT / Digital, Intelligence artificielle / Machine Learning, Logiciels'}
# {'name': 'ZE APPART', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ze-appart', 'website': None, 'category': "Accompagnement d'entreprises, Immobilier commercial, Immobilier particulier"}
# {'name': 'MagicPost', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/magicpost', 'website': None, 'category': 'AdTech / MarTech, Digital Marketing / Data Marketing, Intelligence artificielle / Machine Learning'}
# {'name': 'Weproc', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/weproc', 'website': 'https://www.weproc.com/', 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}
# {'name': 'Barz', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/barz', 'website': 'https://www.barzchocolate.com/', 'category': 'E-commerce, FoodTech, Marketing / Communication'}
# {'name': 'YOUMANIO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/youmanio', 'website': 'https://www.youmanio.com/', 'category': 'Finance, Organisation / Management, Transformation'}
# {'name': 'Enky', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/enky', 'website': 'https://www.enky.com/', 'category': 'Aménagement / Design, Coworking, E-commerce'}
# {'name': 'Maison Carrousel', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/maison-carrousel', 'website': 'https://maison-carrousel.com/', 'category': 'Agroalimentaire / Nutrition animale, Artisanat de bouche, Epicerie fine'}
# {'name': 'EXO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/exo', 'website': None, 'category': 'Application mobile, SaaS / Cloud Services, Sport'}
# {'name': 'ONTOMANTICS', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ontomantics', 'website': None, 'category': 'IT / Digital, Intelligence artificielle / Machine Learning, Logiciels'}
# {'name': 'Crédit Foncier', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/credit-foncier-1', 'website': 'https://www.creditfoncier.com/', 'category': 'Banque, Finance'}
# {'name': 'Savana', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/savana', 'website': 'https://savana-games.com/', 'category': 'Art de vivre, E-commerce, Edition'}
# {'name': 'Holidu', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/holidu', 'website': 'https://www.holidu.fr/', 'category': 'Loisirs, SaaS / Cloud Services, Tourisme'}
# {'name': 'S2i Evolution', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/s2i-evolution', 'website': 'https://www.s2i-agence-web.fr/', 'category': 'Digital, E-commerce, Logiciels'}
# {'name': 'CPA', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cpa', 'website': 'https://www.audit-cpa.com/', 'category': 'Audit, Expertise comptable, Transaction Services'}
# {'name': 'Cedric Grolet', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cedric-grolet-opera', 'website': 'https://www.cedric-grolet.com/', 'category': 'Artisanat de bouche'}
# {'name': 'École Spéciale d’Architecture', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/esa-paris-net', 'website': 'https://www.esa-paris.fr/', 'category': 'Architecture, Education'}
# 💾 Progress saved after page 5 — total 150 companies
#
# --- Scraping page 6 ---
# {'name': 'Fondation Notre Dame', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/fondation-notre-dame', 'website': 'https://www.fondationnotredame.fr/', 'category': 'Association, Fondation, Musées / Institutions culturelles'}
# {'name': 'DesCodeuses', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/descodeuses', 'website': 'https://www.descodeuses.org/', 'category': 'Digital, EdTech, Education'}
# {'name': 'Réseau Ducretet', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/reseau-ducretet', 'website': 'https://www.ducretet.net/', 'category': 'Education, Formation, Recrutement'}
# {'name': 'ZENITY', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/zenity', 'website': 'https://zenity.fr/', 'category': 'IT / Digital'}
# {'name': 'CAPCO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/the-capital-markets-company', 'website': 'https://www.capco.com/', 'category': 'Banque, IT / Digital, Organisation / Management, Transformation'}
# {'name': 'Display Interactive', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/display-interactive', 'website': 'https://display.aero/', 'category': 'Aéronautique / Spatiale, Logiciels'}
# {'name': 'Solinest', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/solinest', 'website': 'https://www.solinest.com/', 'category': 'Agroalimentaire / Nutrition animale, Grande distribution'}
# {'name': 'Yamzho GROUP', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/yamzho-group', 'website': 'https://yamzho-group.fr/', 'category': 'Digital, Marketing / Communication, Stratégie'}
# {'name': 'Eklo Hotels', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/eklo-hotels', 'website': 'https://www.eklohotels.com/', 'category': 'Hôtellerie, Loisirs, Tourisme'}
# {'name': 'Koncrete', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/koncrete', 'website': 'https://www.koncrete.fr/', 'category': 'Bâtiment / Travaux publics, Environnement / Développement durable, Logistique'}
# {'name': 'SNCF RETAIL & CONNEXIONS', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/retail-connexions', 'website': 'https://commercialisations.retail-connexions-sncf.fr/', 'category': 'Immobilier commercial'}
# {'name': 'Circle Sas', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/circle-sas-1', 'website': 'https://www.circle-mobility.com/', 'category': 'Automobile, Logiciels, Mobilité'}
# {'name': 'Sfil', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/sfil', 'website': 'https://www.sfil.fr/', 'category': 'Banque, Finance'}
# {'name': 'Les filles de l ouest', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/les-filles-de-l-ouest', 'website': 'https://www.fillesdelouest.com/', 'category': 'Boissons'}
# {'name': 'WIIKAN', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wiikan', 'website': 'https://www.wiikan.fr/', 'category': 'Immobilier commercial'}
# {'name': 'Base France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/base-com', 'website': 'https://base.com/fr-FR/home', 'category': 'E-commerce, Logiciels, SaaS / Cloud Services'}
# {'name': 'Sia Habitat', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/sia-habitat', 'website': 'https://www.sia-habitat.com/', 'category': 'Immobilier particulier'}
# {'name': 'Early', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/early', 'website': 'https://www.earlyonline.fr/', 'category': 'Digital Marketing / Data Marketing, Marketing / Communication, Tourisme'}
# {'name': 'Hoji', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/hoji', 'website': 'https://www.hojiventures.com/', 'category': 'Environnement / Développement durable, Logiciels, SocialTech / GreenTech'}
# {'name': 'Balguerie Group', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/balguerie', 'website': 'https://balguerie-group.com/', 'category': 'Supply Chain, Transports maritime et routier'}
# {'name': "L'école des hautes études en santé publique", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/l-ehesp', 'website': 'https://www.ehesp.fr/', 'category': 'Administration publique, Administration scolaire et universitaire, Formation'}
# {'name': "Fungu'it", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/fungu-it-1', 'website': 'https://www.funguit.fr/', 'category': 'Agroalimentaire / Nutrition animale'}
# {'name': "SUP'EXPERTISE", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/sup-expertise', 'website': 'https://www.supexpertise.fr/', 'category': 'Association, Education, Formation'}
# {'name': 'Vizzia', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/vizzia', 'website': 'https://www.vizzia.fr/', 'category': 'Objets connectés, SaaS / Cloud Services, SocialTech / GreenTech'}
# {'name': 'Zenride', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/zenride', 'website': 'https://zenride.co/', 'category': 'Environnement / Développement durable, Logiciels, Mobilité'}
# {'name': 'WLF', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wlf-services-1', 'website': 'https://www.wlf-services.fr/', 'category': 'Cybersécurité, IT / Digital, Ressources humaines'}
# {'name': 'Morel Energies SAS', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/morel-energies', 'website': 'https://morel-energies.com/', 'category': "Bureau d'études et d'ingénierie, Energie, Immobilier commercial"}
# {'name': 'Qanopee', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/qanopee', 'website': 'https://www.qanopee.com/', 'category': "Accompagnement d'entreprises, SaaS / Cloud Services, Santé"}
# {'name': 'LITTLE CIGOGNE', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/little-cigogne', 'website': 'https://www.littlecigogne.com/', 'category': 'E-commerce, Mode'}
# {'name': 'MODULOPI', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/modulopi', 'website': None, 'category': "Bureau d'études et d'ingénierie, Ferroviaire, Mobilité"}
# 💾 Progress saved after page 6 — total 180 companies
#
# --- Scraping page 7 ---
# {'name': 'Wizito', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wizito', 'website': 'https://www.wizito.com/', 'category': 'Evénementiel'}
# {'name': 'Solugryn', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/solugryn', 'website': 'https://www.solugryn.fr/', 'category': "Bureau d'études et d'ingénierie, Bâtiment / Travaux publics, Energie"}
# {'name': 'Avril', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/avril-fr', 'website': 'https://www.avril.com/', 'category': 'Agroalimentaire / Nutrition animale, Environnement / Développement durable, SocialTech / GreenTech'}
# {'name': 'Havas France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/havas-sa', 'website': 'https://www.havas.fr/', 'category': 'Marketing / Communication, Publicité, Stratégie'}
# {'name': "L'Armoire À Beauté", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/l-armoire-a-beaute', 'website': 'https://www.larmoireabeaute.com/', 'category': 'Cosmétique, Distribution sélective, E-commerce'}
# {'name': 'Flatpay', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/flatpay', 'website': 'https://www.flatpay.fr/', 'category': 'FinTech / InsurTech'}
# {'name': 'Locomotive', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/locomotive-fr', 'website': 'https://www.locomotive.fr/', 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}
# {'name': 'The Whisky Lodge', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/the-whisky-lodge', 'website': 'https://www.whiskylodge.com/', 'category': 'Boissons, Hôtellerie, Luxe'}
# {'name': 'Wopilo', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wopilo', 'website': 'https://www.wopilo.com/', 'category': 'E-commerce'}
# {'name': 'Ziggy', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ziggy', 'website': 'https://www.ziggyfamily.com/', 'category': 'Agroalimentaire / Nutrition animale'}
# {'name': 'Invent App', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/invent-app', 'website': 'https://invent-app.com/', 'category': 'Application mobile, Evénementiel, SaaS / Cloud Services'}
# {'name': 'Agrilifestudio', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/agrilifestudio', 'website': 'https://www.agrilifestudio.com/', 'category': "Accompagnement d'entreprises, Agroalimentaire / Nutrition animale, Environnement / Développement durable"}
# {'name': 'Hodós Capital', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/hodos-capital', 'website': 'https://hodos-capital.com/', 'category': "Accompagnement d'entreprises, Association, Incubateur / Accélérateur"}
# {'name': 'leakmited', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/leakmited', 'website': 'https://www.leakmited.com/', 'category': 'SaaS / Cloud Services'}
# {'name': 'Impulse Partners', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/impulse-partners', 'website': 'https://www.impulse-partners.com/', 'category': "Accompagnement d'entreprises, Incubateur / Accélérateur, Stratégie"}
# {'name': 'Shangri-La Paris', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/shangri-la-paris', 'website': 'https://www.shangri-la.com/fr/paris/shangrila', 'category': 'Hôtellerie, Luxe, Restauration'}
# {'name': 'APRR-AREA', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/aprr', 'website': 'https://aprr.com/', 'category': 'Logistique, Mobilité, Transports maritime et routier'}
# {'name': 'Family Ventures', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/family-ventures', 'website': 'https://www.familyventures.vc/', 'category': "Accompagnement d'entreprises, Finance, Stratégie"}
# {'name': 'Hellowork group', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/hellowork', 'website': 'https://www.hellowork-group.com/', 'category': 'Formation, Recrutement, Ressources humaines'}
# {'name': 'SHIVA', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/fargo-invest', 'website': 'https://www.shiva.fr/', 'category': 'Services à la personne'}
# {'name': 'Greenspot', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/green-spot', 'website': 'https://www.greenspot.fr/', 'category': 'Energie, Environnement / Développement durable, SocialTech / GreenTech'}
# {'name': 'Castorama France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/castorama-1', 'website': 'https://www.emploi.castorama.fr/', 'category': 'E-commerce, Grande distribution'}
# {'name': 'Kingfisher', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/kingfisher-france', 'website': 'https://www.kingfisher.com/en/index.html', 'category': 'Distribution sélective, Grande distribution'}
# {'name': 'CAVEC', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cavec', 'website': 'https://www.cavec.fr/', 'category': 'Administration publique, Assurance, Finance'}
# {'name': 'ICONIC LIFE', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/iconic-house', 'website': 'https://www.iconic.house/', 'category': 'Hôtellerie, Média, Tourisme'}
# {'name': 'Kolecto', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/kolecto', 'website': 'https://www.kolecto.fr/', 'category': 'Application mobile, FinTech / InsurTech, SaaS / Cloud Services'}
# {'name': 'Lyleoo', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/lyleoo', 'website': 'https://www.lyleoo.com/', 'category': 'Logiciels, Santé'}
# {'name': 'FNEHAD', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/fnehad', 'website': 'https://www.fnehad.fr/', 'category': 'Santé'}
# {'name': 'Stonal', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/stonal', 'website': 'https://stonal.com/', 'category': 'Intelligence artificielle / Machine Learning, SaaS / Cloud Services'}
# {'name': 'Aareon France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/aareon', 'website': 'https://www.aareon.fr/', 'category': 'Application mobile, IT / Digital, Logiciels'}
# 💾 Progress saved after page 7 — total 210 companies
#
# --- Scraping page 8 ---
# {'name': 'MS4D MAKE SENSE FOR DIGITAL', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/make-sense-for-digital', 'website': 'https://www.make-sense.digital/', 'category': 'AdTech / MarTech, Digital, Digital Marketing / Data Marketing'}
# {'name': 'SIMPLON', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/simplon-co-1', 'website': 'https://www.simplon.co/', 'category': 'EdTech, Education, Formation'}
# {'name': 'Apex Education', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/apex-education', 'website': 'https://apex-education.com/', 'category': 'Administration scolaire et universitaire, EdTech, Education'}
# {'name': 'Kenko', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/kenko', 'website': 'https://www.kenko.fr/', 'category': 'Assurance, FinTech / InsurTech'}
# {'name': 'Fifteen', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/fifteen', 'website': 'https://www.fifteen.eu/fr', 'category': 'Environnement / Développement durable, Objets connectés, Économie collaborative'}
# {'name': 'STAR INVEST', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/star-invest-1', 'website': 'https://www.starinvest.fr/', 'category': 'Finance'}
# {'name': 'ONIVERSE', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/calzedonia', 'website': 'https://www.oniverse.it/fr', 'category': 'E-commerce, Mode, Restauration'}
# {'name': 'Clap Partners', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/clap-partners-fr', 'website': 'https://www.clap-partners.com/', 'category': 'IT / Digital, Ressources humaines, SaaS / Cloud Services'}
# {'name': 'Initiative France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/initiative-france', 'website': 'https://www.initiative-france.fr/', 'category': "Accompagnement d'entreprises, Association, Incubateur / Accélérateur"}
# {'name': 'The ART Company', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/rawagency-org', 'website': 'https://www.raw-people.com/', 'category': 'Evénementiel, Musique, Média'}
# {'name': 'DOXALLIA', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/doxallia', 'website': 'https://www.doxio.com/', 'category': 'Cybersécurité, Logiciels, SaaS / Cloud Services'}
# {'name': 'Bonsoirs', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bonsoirs', 'website': 'https://bonsoirs.com/', 'category': 'Art de vivre, Distribution sélective, E-commerce'}
# {'name': "Communauté de communes pays d'Évian - vallée d'Abondance", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/communaute-de-communes-pays-d-evian-vallee-d-a', 'website': 'https://www.cc-peva.fr/', 'category': 'Administration publique, Collectivités publiques et territoriales'}
# {'name': 'Dronisos', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dronisos', 'website': 'https://www.dronisos.com/', 'category': 'Objets connectés'}
# {'name': 'Stilla Technologies', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/stilla-technologies', 'website': 'http://www.stillatechnologies.com/', 'category': 'Pharmaceutique / Biotechnologique, Santé'}
# {'name': 'Nabu', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/nabu', 'website': 'https://nabu.io/', 'category': 'Intelligence artificielle / Machine Learning, Logistique, SaaS / Cloud Services'}
# {'name': 'Le 17.45', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/jolirond-enseigne-le-17-45', 'website': 'https://www.le17-45.fr/', 'category': 'Epicerie fine, Restauration'}
# {'name': "Département Du Val D'Oise", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/departement-du-val-d-oise', 'website': 'http://www.valdoise.fr/', 'category': 'Administration publique, Collectivités publiques et territoriales, Services à la personne'}
# {'name': 'Affluences', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/affluences', 'website': 'https://www.affluences.com/', 'category': 'Application mobile, Objets connectés'}
# {'name': 'Valmi', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/valmi', 'website': 'https://www.valmi-expert.fr/', 'category': 'Immobilier commercial, Immobilier particulier'}
# {'name': 'Revolugo', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/revolugo', 'website': 'http://www.revolugo.com/', 'category': 'Hôtellerie, Logiciels, SaaS / Cloud Services, Tourisme'}
# ...
# {'name': 'THE SKY', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/the-sky', 'website': 'https://thesky.fr/', 'category': 'Cosmétique, Pharmaceutique / Biotechnologique, Santé'}
# {'name': 'Abiléo', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/abileo', 'website': 'https://www.abileo.com/', 'category': 'Audit, Digital Marketing / Data Marketing, Marketing / Communication'}
# {'name': 'Mouratoglou Academy & Resort', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mouratoglou-tennis-academy', 'website': 'http://www.mouratoglou.com/', 'category': 'Education, Hôtellerie, Sport'}
# {'name': 'Trampoline Park You Jump', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/trampoline-park-you-jump-france', 'website': 'https://www.trampolinepark.fr/', 'category': 'Loisirs'}
# {'name': 'SPRiNG', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/spring-1', 'website': 'https://www.cleancollective.com/', 'category': 'E-commerce, Grande distribution, Marketing / Communication'}
# {'name': 'La France Mutualiste', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/la-france-mutualiste', 'website': 'https://www.la-france-mutualiste.fr/', 'category': 'Assurance'}
# {'name': 'GROW', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/grow', 'website': 'https://www.grow-ps.com/fr', 'category': "Accompagnement d'entreprises, Marketing / Communication, Stratégie"}
# {'name': 'JJA', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/jja', 'website': 'http://www.jja-sa.fr/', 'category': 'Art de vivre, E-commerce, Grande distribution'}
# {'name': 'Theodo GovTech', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/solona', 'website': None, 'category': 'Administration publique, Application mobile, Logiciels'}
# {'name': 'OLIVER', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/oliver', 'website': 'https://www.oliver.agency/', 'category': 'Digital, Marketing / Communication, Publicité'}
# {'name': 'Intranet Inside', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/intranet-inside', 'website': 'https://www.intranet-inside.com/', 'category': 'Digital, IT / Digital, Logiciels'}
# {'name': 'Maison Coudène', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/coudene', 'website': 'https://coudene.com/', 'category': 'Agroalimentaire / Nutrition animale'}
# {'name': "L'Étincelle", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/l-etincelle-1', 'website': 'https://www.letincelle.co/', 'category': 'Energie'}
# {'name': 'Shortlinks', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/shortlinks', 'website': 'https://shortlinks.fr/', 'category': 'Marketing / Communication'}
# {'name': 'TDI', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/tdi', 'website': 'https://www.tdi-group.com/fr/carriere', 'category': 'Logiciels, Logistique, SaaS / Cloud Services'}
# {'name': 'Le Colibri', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/le-colibri', 'website': 'https://colibri-asso.fr/', 'category': 'Education, ONG'}
# {'name': 'ELCIA Groupe', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/elcia-groupe', 'website': 'https://www.elcia.com/', 'category': 'Logiciels, SaaS / Cloud Services'}
# {'name': 'each One', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/each-one', 'website': 'https://eachone.co/', 'category': 'Formation, Recrutement'}
# 💾 Progress saved after page 32 — total 960 companies
#
# --- Scraping page 33 ---
# {'name': 'Michel et Augustin', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/michel-et-augustin-1', 'website': 'https://www.micheletaugustin.com/', 'category': 'Agroalimentaire / Nutrition animale, Epicerie fine, Grande consommation'}
# {'name': 'Eurogroup Consulting', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/eurogroup-consulting', 'website': 'http://www.eurogroupconsulting.com/', 'category': 'Organisation / Management, Stratégie'}
# {'name': 'HelloCSE', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/hellocse', 'website': 'https://www.hellocse.fr/', 'category': 'Application mobile'}
# {'name': 'Deliveroo', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/deliveroo', 'website': 'https://deliveroo.fr/', 'category': 'Application mobile, E-commerce, FoodTech'}
# {'name': 'Ipesup', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ipesup', 'website': 'https://www.ipesup.fr/', 'category': 'Education, Formation'}
# {'name': 'CONFIRM IT', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/confirm-it', 'website': 'http://www.confirmit-group.com/', 'category': 'Cybersécurité, FinTech / InsurTech, SaaS / Cloud Services'}
# {'name': 'Arcane', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/arcane', 'website': 'https://arcane.run/', 'category': 'Digital, Marketing / Communication, Publicité'}
# {'name': 'AISI', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/aisi', 'website': 'https://aisi.fr/', 'category': 'Cybersécurité'}
# {'name': 'Responsage', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/responsage', 'website': 'https://www.responsage.com/', 'category': "Accompagnement d'entreprises, Ressources humaines, Services à la personne"}
# {'name': '2600', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ecole-2600', 'website': 'https://ecole2600.com/', 'category': 'Cybersécurité, EdTech, Formation'}
# {'name': 'LFB', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/lfb', 'website': 'https://www.groupe-lfb.com/', 'category': 'Pharmaceutique / Biotechnologique'}
# {'name': 'ASTRAVEUS', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/astraveus-1', 'website': 'https://www.astraveus.com/', 'category': 'Ingénieries Spécialisées, Pharmaceutique / Biotechnologique, Santé'}
# {'name': 'Visum', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/visum', 'website': 'https://www.visum.run/', 'category': ''}
# {'name': 'ASight', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/a-sight', 'website': 'https://www.asight.fr/', 'category': ''}
# {'name': 'SKYREAL', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/skyreal', 'website': 'https://skyreal.tech/', 'category': 'Electronique / Télécommunications, Intelligence artificielle / Machine Learning, SaaS / Cloud Services'}
# {'name': 'Fondation FondaMental', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/fondation-fondamental', 'website': 'https://www.fondation-fondamental.org/', 'category': 'Fondation, ONG, Pharmaceutique / Biotechnologique, Santé'}
# {'name': 'OpenDecide', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/opendecide', 'website': 'https://opendecide.com/', 'category': 'Intelligence artificielle / Machine Learning, Organisation / Management, SaaS / Cloud Services'}
# {'name': 'Groupe Octime', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/octime', 'website': 'https://www.octime.com/', 'category': 'Logiciels, SaaS / Cloud Services'}
# {'name': 'Le Mans Endurance Management', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/le-mans-endurance-management', 'website': 'https://www.fiawec.com/', 'category': 'Automobile, Evénementiel, Sport'}
# {'name': 'GS1 France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/gs1-france', 'website': 'https://www.gs1.fr/', 'category': 'Grande distribution, IT / Digital, Économie collaborative'}
# {'name': 'Telecom Design', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/telecom-design', 'website': 'https://telecom-design.com/', 'category': 'Objets connectés'}
# {'name': 'MYTRAFFIC', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mytraffic', 'website': 'https://www.mytraffic.io/en', 'category': 'SaaS / Cloud Services'}
# {'name': 'Optima Prévention', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/optima-prevention', 'website': 'https://www.optimarh.com/', 'category': 'Organisation / Management'}
# {'name': 'Groupe Scet', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/scet', 'website': 'https://www.scet.fr/', 'category': 'Aménagement / Design, Collectivités publiques et territoriales, Organisation / Management, Stratégie, Transformation'}
# {'name': 'Picadeli', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/picadeli', 'website': 'https://www.picadeli.com/fr', 'category': 'FoodTech'}
# {'name': 'Estaly', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/estaly', 'website': 'https://www.estaly.co/', 'category': 'Assurance, E-commerce, FinTech / InsurTech'}
# {'name': 'YMAG', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ymag-sas', 'website': 'https://www.ymag.fr/', 'category': 'EdTech, Logiciels, SaaS / Cloud Services'}
# {'name': 'Dynatrace', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/dynatrace', 'website': 'https://careers.dynatrace.com/?utm_source=job-boards&utm_medium=company-profile&utm_campaign=WelcomeToTheJungle', 'category': 'IT / Digital, Logiciels, SaaS / Cloud Services'}
# {'name': 'Lenstra', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/lenstra', 'website': 'https://lenstra.co/', 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}
# {'name': 'Expertify', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/expertify', 'website': 'https://expertify.store/', 'category': 'Digital Marketing / Data Marketing, E-commerce, IT / Digital'}
# 💾 Progress saved after page 33 — total 990 companies
#
# --- Scraping page 34 ---
# {'name': 'Stx Commodities France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/stx-commodities-france', 'website': 'https://stxgroup.com/', 'category': 'Energie, Finance, Mobilité'}
# {'name': 'Eurovanille', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/eurovanille', 'website': 'https://eurovanille.com/fr_FR', 'category': 'Agroalimentaire / Nutrition animale'}
# {'name': 'A4MT Action for Market Transformation', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/a4mt', 'website': 'https://a4mt.com/fr', 'category': 'Environnement / Développement durable, Stratégie, Transformation'}
# {'name': 'IDEO', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/id-logistics', 'website': 'https://www.id-logistics.com/fr', 'category': 'Logistique'}
# {'name': 'Synapse Risk & Compliance', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/syspertec-group', 'website': 'https://www.synapse-rc.com/index.html', 'category': 'FinTech / InsurTech, Logiciels, Service juridique'}
# {'name': 'Groupe VYV', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/groupe-vyv', 'website': 'https://www.groupe-vyv.fr/rejoignez-nous', 'category': 'Assurance, Services à la personne'}
# {'name': 'IRTS Parmentier', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/irts-parmentier', 'website': 'https://www.irtsparmentier.fr/', 'category': 'Association, Formation, Services à la personne'}
# {'name': 'Atlante France', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/atlante-france-sas', 'website': 'https://atlante.energy/fr', 'category': 'Energie, Environnement / Développement durable, Mobilité'}
# {'name': 'Bizon (Publicis Groupe)', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bizon', 'website': 'https://www.bizon.solutions/', 'category': 'Digital'}
# {'name': 'Chauvin Arnoux Group', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/chauvin-arnoux', 'website': 'https://www.group.chauvin-arnoux.com/fr', 'category': 'Energie, Ingénieries Spécialisées'}
# 💾 Progress saved after page 34 — total 1000 companies
# Scraped companies: [{'name': 'Renaissance Studio', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/renaissance-studio', 'website': 'https://www.rowads.app/', 'category': 'AdTech / MarTech, Intelligence artificielle / Machine Learning, Publicité'}, {'name': 'Foxglove', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/foxglove', 'website': 'https://www.foxglove-partner.com/', 'category': 'Design, Digital, Digital Marketing / Data Marketing'}, {'name': 'Horizon', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/orizon', 'website': None, 'category': 'Digital, Digital Marketing / Data Marketing, Publicité'}, {'name': 'Planon', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/planon', 'website': 'https://planonsoftware.com/fr', 'category': 'IT / Digital, Logiciels, SaaS / Cloud Services'}, {'name': 'Eurowind Energy', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/eurowindenergy', 'website': 'https://eurowindenergy.com/fr', 'category': 'Energie, Environnement / Développement durable'}, {'name': 'Wyes', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/wyes', 'website': 'https://www.wyes.fr/', 'category': 'Intelligence artificielle / Machine Learning, Objets connectés, Santé'}, {'name': 'Heex Technologies', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/heex', 'website': 'https://heex.io/', 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}, {'name': 'La Tête Dans Les Nuages', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/la-tete-dans-les-nuages-1', 'website': 'https://www.ltdln.com/', 'category': 'Aménagement / Design, Art de vivre, E-commerce'}, {'name': 'MOBILITEAM', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/mobiliteam', 'website': 'https://www.cacd.fr/', 'category': 'Aménagement / Design, Architecture, Bâtiment / Travaux publics'}, {'name': 'PARIFEX', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/parifex', 'website': 'https://www.parifex.com/', 'category': "Bureau d'études et d'ingénierie, Mobilité"}, {'name': 'OREVE', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/oreve', 'website': 'https://www.ortec-group.com/', 'category': 'Environnement / Développement durable, Mobilité'}, {'name': "Centre National du cinéma et de l'Image animée", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/cnc-fr', 'website': 'https://www.cnc.fr/', 'category': 'Cinéma, Musées / Institutions culturelles, Télévision / Production audiovisuelle'}, {'name': 'Bacchus / Cérès', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/bacchus-services', 'website': 'https://www.bacchus-services.com/', 'category': 'Boissons, Epicerie fine, Restauration'}, {'name': 'Atelier Ticho', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/atelier-ticho', 'website': None, 'category': "Architecture, Bureau d'études et d'ingénierie, Bâtiment / Travaux publics"}, {'name': 'Ville de Talence', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ville-de-talence', 'website': 'https://www.talence.fr/', 'category': 'Collectivités publiques et territoriales, Relations publiques, Ressources humaines'}, {'name': 'Quadient', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/quadient', 'website': 'https://www.quadient.com/', 'category': 'IT / Digital, Logiciels'}, {'name': "Ministère de l'Agriculture et de la Souveraineté alimentaire", 'detail_page': 'https://www.welcometothejungle.com/fr/companies/ministere-de-l-agriculture-et-de-la-souveraine', 'website': 'https://www.agriculture.gouv.fr/', 'category': 'Administration publique'}, {'name': 'Delos', 'detail_page': 'https://www.welcometothejungle.com/fr/companies/delos', 'website': None, 'category': 'Intelligence artificielle / Machine Learning, Logiciels, SaaS / Cloud Services'}, {'name': 'Phagos', 'detail_page': 'https://www.welcometothejungle.com/fr/ ...

# %%
# df = pd.DataFrame(results)

# df.to_excel("scraped_companies.xlsx", index=False)

# print("Saved to scraped_companies.xlsx")
